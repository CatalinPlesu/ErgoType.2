# %%
import os
import pickle
from keyboard_phenotype import KeyboardPhenotype
from kle.kle_model import Serial, FingerName
from keyboard_genotypes import LAYOUT_DATA
from kle.kle_renderer import show_keyboard, render_keyboard

try:
    data_file = './processed/markov_chains.pkl'
    if not os.path.exists(data_file):
        print(f"ERROR: Data file not found: {data_file}")
        data = {}
    else:
        with open(data_file, 'rb') as f:
            data = pickle.load(f)
        print(f"✅ Successfully loaded data from {data_file}")
except Exception as e:
    print(f"ERROR loading data: {e}")
    data = {}
# Out:
# ✅ Successfully loaded data from ./processed/markov_chains.pkl

# %%
with open('kle_keyboards/ansi_60_percent_hands.json', 'r') as f:
    keyboard = Serial.parse(f.read())

keyboard = KeyboardPhenotype(keyboard, {})

keyboard.select_remap_keys(LAYOUT_DATA['qwerty'])
keyboard.remap_to_keys(LAYOUT_DATA['asset'])
# keyboard.fitness(data['simple_wikipedia'])
show_keyboard(keyboard.get_phisical_keyboard())
# Out:
# Init keyboard phenotype
# Key is unneeded ('Backspace',)
# Key is unneeded ('Caps Lock',)
# Key is unneeded ('Ctrl',)
# Key is unneeded ('Win',)
# Key is unneeded ('Alt',)
# Key is unneeded ('Win',)
# Key is unneeded ('Menu',)
# Key is unneeded ('Ctrl',)
# {'q': 'q', 'w': 'w', 'e': 'j', 'r': 'f', 't': 'g', 'y': 'y', 'u': 'p', 'i': 'u', 'o': 'l', 'p': ';', '[': '[', ']': ']', '\\': '\\', 'a': 'a', 's': 's', 'd': 'e', 'f': 't', 'g': 'd', 'h': 'h', 'j': 'n', 'k': 'i', 'l': 'o', ';': 'r', "'": "'", 'z': 'z', 'x': 'x', 'c': 'c', 'v': 'v', 'b': 'b', 'n': 'k', 'm': 'm', ',': ',', '.': '.', '/': '/'}

# %%
show_keyboard(keyboard.get_physical_keyboard_with_costs())

# %%
import matplotlib.pyplot as plt

# Collect fitness values
fitness_values = []
layout_keys = []

for key, value in LAYOUT_DATA.items():
    print(key)
    keyboard.remap_to_keys(value)
    fitness = keyboard.fitness(data['simple_wikipedia'])  # Store the returned fitness value
    fitness_values.append(fitness)
    layout_keys.append(key)
    show_keyboard(keyboard.get_phisical_keyboard())
# Out:
# qwerty
# {'q': 'q', 'w': 'w', 'e': 'e', 'r': 'r', 't': 't', 'y': 'y', 'u': 'u', 'i': 'i', 'o': 'o', 'p': 'p', '[': '[', ']': ']', '\\': '\\', 'a': 'a', 's': 's', 'd': 'd', 'f': 'f', 'g': 'g', 'h': 'h', 'j': 'j', 'k': 'k', 'l': 'l', ';': ';', "'": "'", 'z': 'z', 'x': 'x', 'c': 'c', 'v': 'v', 'b': 'b', 'n': 'n', 'm': 'm', ',': ',', '.': '.', '/': '/'}
# Total cost: 851,823.74
# Total presses: 1,000,003.0
# minimak
# {'q': 'q', 'w': 'w', 'e': 'd', 'r': 'f', 't': 'k', 'y': 'y', 'u': 'u', 'i': 'i', 'o': 'l', 'p': ';', '[': '[', ']': ']', '\\': '\\', 'a': 'a', 's': 's', 'd': 't', 'f': 'r', 'g': 'g', 'h': 'h', 'j': 'n', 'k': 'e', 'l': 'o', ';': 'p', "'": "'", 'z': 'z', 'x': 'x', 'c': 'c', 'v': 'v', 'b': 'b', 'n': 'j', 'm': 'm', ',': ',', '.': '.', '/': '/'}
# Total cost: 579,194.17
# Total presses: 1,000,003.0
# dvorak
# {'q': "'", 'w': ',', 'e': '.', 'r': 'p', 't': 'y', 'y': 'f', 'u': 'g', 'i': 'c', 'o': 'r', 'p': 'l', '[': '/', ']': '=', '\\': '\\', 'a': 'a', 's': 'o', 'd': 'e', 'f': 'u', 'g': 'i', 'h': 'd', 'j': 'h', 'k': 't', 'l': 'n', ';': 's', "'": '-', 'z': ';', 'x': 'q', 'c': 'j', 'v': 'k', 'b': 'x', 'n': 'b', 'm': 'm', ',': 'w', '.': 'v', '/': 'z'}
# Total cost: 948,917.36
# Total presses: 1,000,003.0
# workman
# {'q': 'q', 'w': 'd', 'e': 'r', 'r': 'w', 't': 'b', 'y': 'j', 'u': 'f', 'i': 'u', 'o': 'p', 'p': ';', '[': '[', ']': ']', '\\': '\\', 'a': 'a', 's': 's', 'd': 'h', 'f': 't', 'g': 'g', 'h': 'y', 'j': 'n', 'k': 'e', 'l': 'o', ';': 'i', "'": "'", 'z': 'z', 'x': 'x', 'c': 'm', 'v': 'c', 'b': 'v', 'n': 'k', 'm': 'l', ',': ',', '.': '.', '/': '/'}
# Total cost: 830,401.72
# Total presses: 1,000,003.0
# norman
# {'q': 'q', 'w': 'w', 'e': 'd', 'r': 'f', 't': 'k', 'y': 'j', 'u': 'u', 'i': 'r', 'o': 'l', 'p': ';', '[': '[', ']': ']', '\\': '\\', 'a': 'a', 's': 's', 'd': 'e', 'f': 't', 'g': 'g', 'h': 'y', 'j': 'n', 'k': 'i', 'l': 'o', ';': 'h', "'": "'", 'z': 'z', 'x': 'x', 'c': 'c', 'v': 'v', 'b': 'b', 'n': 'p', 'm': 'm', ',': ',', '.': '.', '/': '/'}
# Total cost: 640,424.22
# Total presses: 1,000,003.0
# asset
# {'q': 'q', 'w': 'w', 'e': 'j', 'r': 'f', 't': 'g', 'y': 'y', 'u': 'p', 'i': 'u', 'o': 'l', 'p': ';', '[': '[', ']': ']', '\\': '\\', 'a': 'a', 's': 's', 'd': 'e', 'f': 't', 'g': 'd', 'h': 'h', 'j': 'n', 'k': 'i', 'l': 'o', ';': 'r', "'": "'", 'z': 'z', 'x': 'x', 'c': 'c', 'v': 'v', 'b': 'b', 'n': 'k', 'm': 'm', ',': ',', '.': '.', '/': '/'}
# Total cost: 628,649.70
# Total presses: 1,000,003.0
# colemak
# {'q': 'q', 'w': 'w', 'e': 'f', 'r': 'p', 't': 'g', 'y': 'j', 'u': 'l', 'i': 'u', 'o': 'y', 'p': ';', '[': '[', ']': ']', '\\': '\\', 'a': 'a', 's': 'r', 'd': 's', 'f': 't', 'g': 'd', 'h': 'h', 'j': 'n', 'k': 'e', 'l': 'i', ';': 'o', "'": "'", 'z': 'z', 'x': 'x', 'c': 'c', 'v': 'v', 'b': 'b', 'n': 'k', 'm': 'm', ',': ',', '.': '.', '/': '/'}
# Total cost: 753,241.55
# Total presses: 1,000,003.0

# %%
# Plot the fitness values in a bar chart
plt.figure(figsize=(10, 6))
plt.bar(layout_keys, fitness_values)
plt.xlabel('Layout')
plt.ylabel('Fitness Value')
plt.title('Fitness Values for Different Layouts')
plt.xticks(rotation=45)  # Rotate x-axis labels if there are many layouts
plt.tight_layout()  # Adjust layout to prevent label cutoff
plt.show()

# %%
import matplotlib.pyplot as plt

# Blacklist specific dataset
BLACKLISTED_DATASET = ['cartigratis']
DATASETS = data

# Collect fitness values for all layouts and datasets (except blacklisted)
results = {}

for layout_key, layout_value in LAYOUT_DATA.items():
    print(f"Processing layout: {layout_key}")
    results[layout_key] = {}
    
    # Process each dataset except the blacklisted one
    for dataset_name, dataset_data in DATASETS.items():
        print(f"processing dataset {dataset_name}")
        if dataset_name not in BLACKLISTED_DATASET:  # Skip blacklisted dataset
            keyboard.remap_to_keys(layout_value)
            fitness = keyboard.fitness(dataset_data)
            results[layout_key][dataset_name] = fitness
            print(f"  {dataset_name}: {fitness}")
        else:
            print(f"  Skipping blacklisted dataset: {dataset_name}")
    
    show_keyboard(keyboard.get_phisical_keyboard())

# Create bar charts for each non-blacklisted dataset
for dataset_name in DATASETS.keys():
    if dataset_name not in BLACKLISTED_DATASET:
        layout_keys = list(LAYOUT_DATA.keys())
        fitness_values = [results[layout_key][dataset_name] for layout_key in layout_keys]
        
        plt.figure(figsize=(10, 6))
        plt.bar(layout_keys, fitness_values)
        plt.xlabel('Layout')
        plt.ylabel('Fitness Value')
        plt.title(f'Fitness Values for Different Layouts - Dataset: {dataset_name}')
        plt.xticks(rotation=45)
        plt.tight_layout()
        plt.show()

# Grouped bar chart for all non-blacklisted datasets
non_blacklisted_datasets = [name for name in DATASETS.keys() if name not in BLACKLISTED_DATASET]

fig, ax = plt.subplots(figsize=(12, 8))
x = range(len(LAYOUT_DATA))
width = 0.2

for i, dataset_name in enumerate(non_blacklisted_datasets):
    fitness_values = [results[layout_key][dataset_name] for layout_key in LAYOUT_DATA.keys()]
    ax.bar([pos + i * width for pos in x], fitness_values, width, label=dataset_name)

ax.set_xlabel('Layout')
ax.set_ylabel('Fitness Value')
ax.set_title('Fitness Values for Different Layouts Across Multiple Datasets (Excluding catrigratis)')
ax.set_xticks([pos + width * (len(non_blacklisted_datasets)-1) / 2 for pos in x])
ax.set_xticklabels(LAYOUT_DATA.keys())
ax.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Processing layout: qwerty
# processing dataset simple_wikipedia
# {'q': 'q', 'w': 'w', 'e': 'e', 'r': 'r', 't': 't', 'y': 'y', 'u': 'u', 'i': 'i', 'o': 'o', 'p': 'p', '[': '[', ']': ']', '\\': '\\', 'a': 'a', 's': 's', 'd': 'd', 'f': 'f', 'g': 'g', 'h': 'h', 'j': 'j', 'k': 'k', 'l': 'l', ';': ';', "'": "'", 'z': 'z', 'x': 'x', 'c': 'c', 'v': 'v', 'b': 'b', 'n': 'n', 'm': 'm', ',': ',', '.': '.', '/': '/'}
# Total cost: 851,823.74
# Total presses: 1,000,003.0
#   simple_wikipedia: 851823.7404362205
# processing dataset the_algorithms_code
# {'q': 'q', 'w': 'w', 'e': 'e', 'r': 'r', 't': 't', 'y': 'y', 'u': 'u', 'i': 'i', 'o': 'o', 'p': 'p', '[': '[', ']': ']', '\\': '\\', 'a': 'a', 's': 's', 'd': 'd', 'f': 'f', 'g': 'g', 'h': 'h', 'j': 'j', 'k': 'k', 'l': 'l', ';': ';', "'": "'", 'z': 'z', 'x': 'x', 'c': 'c', 'v': 'v', 'b': 'b', 'n': 'n', 'm': 'm', ',': ',', '.': '.', '/': '/'}
# Total cost: 1,034,590.90
# Total presses: 999,998.0
#   the_algorithms_code: 1034590.895594052
# processing dataset gutenberg
# {'q': 'q', 'w': 'w', 'e': 'e', 'r': 'r', 't': 't', 'y': 'y', 'u': 'u', 'i': 'i', 'o': 'o', 'p': 'p', '[': '[', ']': ']', '\\': '\\', 'a': 'a', 's': 's', 'd': 'd', 'f': 'f', 'g': 'g', 'h': 'h', 'j': 'j', 'k': 'k', 'l': 'l', ';': ';', "'": "'", 'z': 'z', 'x': 'x', 'c': 'c', 'v': 'v', 'b': 'b', 'n': 'n', 'm': 'm', ',': ',', '.': '.', '/': '/'}
# Total cost: 798,332.77
# Total presses: 999,998.0
#   gutenberg: 798332.7655823716
# processing dataset cartigratis
#   Skipping blacklisted dataset: cartigratis
# processing dataset newsgroup
# {'q': 'q', 'w': 'w', 'e': 'e', 'r': 'r', 't': 't', 'y': 'y', 'u': 'u', 'i': 'i', 'o': 'o', 'p': 'p', '[': '[', ']': ']', '\\': '\\', 'a': 'a', 's': 's', 'd': 'd', 'f': 'f', 'g': 'g', 'h': 'h', 'j': 'j', 'k': 'k', 'l': 'l', ';': ';', "'": "'", 'z': 'z', 'x': 'x', 'c': 'c', 'v': 'v', 'b': 'b', 'n': 'n', 'm': 'm', ',': ',', '.': '.', '/': '/'}
# Total cost: 1,024,253.19
# Total presses: 999,998.0
#   newsgroup: 1024253.1883880289
# Processing layout: minimak
# processing dataset simple_wikipedia
# {'q': 'q', 'w': 'w', 'e': 'd', 'r': 'f', 't': 'k', 'y': 'y', 'u': 'u', 'i': 'i', 'o': 'l', 'p': ';', '[': '[', ']': ']', '\\': '\\', 'a': 'a', 's': 's', 'd': 't', 'f': 'r', 'g': 'g', 'h': 'h', 'j': 'n', 'k': 'e', 'l': 'o', ';': 'p', "'": "'", 'z': 'z', 'x': 'x', 'c': 'c', 'v': 'v', 'b': 'b', 'n': 'j', 'm': 'm', ',': ',', '.': '.', '/': '/'}
# Total cost: 579,194.17
# Total presses: 1,000,003.0
#   simple_wikipedia: 579194.1724700283
# processing dataset the_algorithms_code
# {'q': 'q', 'w': 'w', 'e': 'd', 'r': 'f', 't': 'k', 'y': 'y', 'u': 'u', 'i': 'i', 'o': 'l', 'p': ';', '[': '[', ']': ']', '\\': '\\', 'a': 'a', 's': 's', 'd': 't', 'f': 'r', 'g': 'g', 'h': 'h', 'j': 'n', 'k': 'e', 'l': 'o', ';': 'p', "'": "'", 'z': 'z', 'x': 'x', 'c': 'c', 'v': 'v', 'b': 'b', 'n': 'j', 'm': 'm', ',': ',', '.': '.', '/': '/'}
# Total cost: 838,270.36
# Total presses: 999,998.0
#   the_algorithms_code: 838270.3575333669
# processing dataset gutenberg
# {'q': 'q', 'w': 'w', 'e': 'd', 'r': 'f', 't': 'k', 'y': 'y', 'u': 'u', 'i': 'i', 'o': 'l', 'p': ';', '[': '[', ']': ']', '\\': '\\', 'a': 'a', 's': 's', 'd': 't', 'f': 'r', 'g': 'g', 'h': 'h', 'j': 'n', 'k': 'e', 'l': 'o', ';': 'p', "'": "'", 'z': 'z', 'x': 'x', 'c': 'c', 'v': 'v', 'b': 'b', 'n': 'j', 'm': 'm', ',': ',', '.': '.', '/': '/'}
# Total cost: 524,743.97
# Total presses: 999,998.0
#   gutenberg: 524743.9696976778
# processing dataset cartigratis
#   Skipping blacklisted dataset: cartigratis
# processing dataset newsgroup
# {'q': 'q', 'w': 'w', 'e': 'd', 'r': 'f', 't': 'k', 'y': 'y', 'u': 'u', 'i': 'i', 'o': 'l', 'p': ';', '[': '[', ']': ']', '\\': '\\', 'a': 'a', 's': 's', 'd': 't', 'f': 'r', 'g': 'g', 'h': 'h', 'j': 'n', 'k': 'e', 'l': 'o', ';': 'p', "'": "'", 'z': 'z', 'x': 'x', 'c': 'c', 'v': 'v', 'b': 'b', 'n': 'j', 'm': 'm', ',': ',', '.': '.', '/': '/'}
# Total cost: 789,291.30
# Total presses: 999,998.0
#   newsgroup: 789291.297358755
# Processing layout: dvorak
# processing dataset simple_wikipedia
# {'q': "'", 'w': ',', 'e': '.', 'r': 'p', 't': 'y', 'y': 'f', 'u': 'g', 'i': 'c', 'o': 'r', 'p': 'l', '[': '/', ']': '=', '\\': '\\', 'a': 'a', 's': 'o', 'd': 'e', 'f': 'u', 'g': 'i', 'h': 'd', 'j': 'h', 'k': 't', 'l': 'n', ';': 's', "'": '-', 'z': ';', 'x': 'q', 'c': 'j', 'v': 'k', 'b': 'x', 'n': 'b', 'm': 'm', ',': 'w', '.': 'v', '/': 'z'}
# Total cost: 948,917.36
# Total presses: 1,000,003.0
#   simple_wikipedia: 948917.3611126028
# processing dataset the_algorithms_code
# {'q': "'", 'w': ',', 'e': '.', 'r': 'p', 't': 'y', 'y': 'f', 'u': 'g', 'i': 'c', 'o': 'r', 'p': 'l', '[': '/', ']': '=', '\\': '\\', 'a': 'a', 's': 'o', 'd': 'e', 'f': 'u', 'g': 'i', 'h': 'd', 'j': 'h', 'k': 't', 'l': 'n', ';': 's', "'": '-', 'z': ';', 'x': 'q', 'c': 'j', 'v': 'k', 'b': 'x', 'n': 'b', 'm': 'm', ',': 'w', '.': 'v', '/': 'z'}
# Total cost: 1,126,002.63
# Total presses: 999,998.0
#   the_algorithms_code: 1126002.6278270893
# processing dataset gutenberg
# {'q': "'", 'w': ',', 'e': '.', 'r': 'p', 't': 'y', 'y': 'f', 'u': 'g', 'i': 'c', 'o': 'r', 'p': 'l', '[': '/', ']': '=', '\\': '\\', 'a': 'a', 's': 'o', 'd': 'e', 'f': 'u', 'g': 'i', 'h': 'd', 'j': 'h', 'k': 't', 'l': 'n', ';': 's', "'": '-', 'z': ';', 'x': 'q', 'c': 'j', 'v': 'k', 'b': 'x', 'n': 'b', 'm': 'm', ',': 'w', '.': 'v', '/': 'z'}
# Total cost: 893,574.14
# Total presses: 999,998.0
#   gutenberg: 893574.1439187704
# processing dataset cartigratis
#   Skipping blacklisted dataset: cartigratis
# processing dataset newsgroup
# {'q': "'", 'w': ',', 'e': '.', 'r': 'p', 't': 'y', 'y': 'f', 'u': 'g', 'i': 'c', 'o': 'r', 'p': 'l', '[': '/', ']': '=', '\\': '\\', 'a': 'a', 's': 'o', 'd': 'e', 'f': 'u', 'g': 'i', 'h': 'd', 'j': 'h', 'k': 't', 'l': 'n', ';': 's', "'": '-', 'z': ';', 'x': 'q', 'c': 'j', 'v': 'k', 'b': 'x', 'n': 'b', 'm': 'm', ',': 'w', '.': 'v', '/': 'z'}
# Total cost: 1,118,921.31
# Total presses: 999,998.0
#   newsgroup: 1118921.312515341
# Processing layout: workman
# processing dataset simple_wikipedia
# {'q': 'q', 'w': 'd', 'e': 'r', 'r': 'w', 't': 'b', 'y': 'j', 'u': 'f', 'i': 'u', 'o': 'p', 'p': ';', '[': '[', ']': ']', '\\': '\\', 'a': 'a', 's': 's', 'd': 'h', 'f': 't', 'g': 'g', 'h': 'y', 'j': 'n', 'k': 'e', 'l': 'o', ';': 'i', "'": "'", 'z': 'z', 'x': 'x', 'c': 'm', 'v': 'c', 'b': 'v', 'n': 'k', 'm': 'l', ',': ',', '.': '.', '/': '/'}
# Total cost: 830,401.72
# Total presses: 1,000,003.0
#   simple_wikipedia: 830401.7194147859
# processing dataset the_algorithms_code
# {'q': 'q', 'w': 'd', 'e': 'r', 'r': 'w', 't': 'b', 'y': 'j', 'u': 'f', 'i': 'u', 'o': 'p', 'p': ';', '[': '[', ']': ']', '\\': '\\', 'a': 'a', 's': 's', 'd': 'h', 'f': 't', 'g': 'g', 'h': 'y', 'j': 'n', 'k': 'e', 'l': 'o', ';': 'i', "'": "'", 'z': 'z', 'x': 'x', 'c': 'm', 'v': 'c', 'b': 'v', 'n': 'k', 'm': 'l', ',': ',', '.': '.', '/': '/'}
# Total cost: 1,033,580.44
# Total presses: 999,998.0
#   the_algorithms_code: 1033580.444936948
# processing dataset gutenberg
# {'q': 'q', 'w': 'd', 'e': 'r', 'r': 'w', 't': 'b', 'y': 'j', 'u': 'f', 'i': 'u', 'o': 'p', 'p': ';', '[': '[', ']': ']', '\\': '\\', 'a': 'a', 's': 's', 'd': 'h', 'f': 't', 'g': 'g', 'h': 'y', 'j': 'n', 'k': 'e', 'l': 'o', ';': 'i', "'": "'", 'z': 'z', 'x': 'x', 'c': 'm', 'v': 'c', 'b': 'v', 'n': 'k', 'm': 'l', ',': ',', '.': '.', '/': '/'}
# Total cost: 789,747.80
# Total presses: 999,998.0
#   gutenberg: 789747.795395752
# processing dataset cartigratis
#   Skipping blacklisted dataset: cartigratis
# processing dataset newsgroup
# {'q': 'q', 'w': 'd', 'e': 'r', 'r': 'w', 't': 'b', 'y': 'j', 'u': 'f', 'i': 'u', 'o': 'p', 'p': ';', '[': '[', ']': ']', '\\': '\\', 'a': 'a', 's': 's', 'd': 'h', 'f': 't', 'g': 'g', 'h': 'y', 'j': 'n', 'k': 'e', 'l': 'o', ';': 'i', "'": "'", 'z': 'z', 'x': 'x', 'c': 'm', 'v': 'c', 'b': 'v', 'n': 'k', 'm': 'l', ',': ',', '.': '.', '/': '/'}
# Total cost: 1,002,938.67
# Total presses: 999,998.0
#   newsgroup: 1002938.6692516175
# Processing layout: norman
# processing dataset simple_wikipedia
# {'q': 'q', 'w': 'w', 'e': 'd', 'r': 'f', 't': 'k', 'y': 'j', 'u': 'u', 'i': 'r', 'o': 'l', 'p': ';', '[': '[', ']': ']', '\\': '\\', 'a': 'a', 's': 's', 'd': 'e', 'f': 't', 'g': 'g', 'h': 'y', 'j': 'n', 'k': 'i', 'l': 'o', ';': 'h', "'": "'", 'z': 'z', 'x': 'x', 'c': 'c', 'v': 'v', 'b': 'b', 'n': 'p', 'm': 'm', ',': ',', '.': '.', '/': '/'}
# Total cost: 640,424.22
# Total presses: 1,000,003.0
#   simple_wikipedia: 640424.2192549838
# processing dataset the_algorithms_code
# {'q': 'q', 'w': 'w', 'e': 'd', 'r': 'f', 't': 'k', 'y': 'j', 'u': 'u', 'i': 'r', 'o': 'l', 'p': ';', '[': '[', ']': ']', '\\': '\\', 'a': 'a', 's': 's', 'd': 'e', 'f': 't', 'g': 'g', 'h': 'y', 'j': 'n', 'k': 'i', 'l': 'o', ';': 'h', "'": "'", 'z': 'z', 'x': 'x', 'c': 'c', 'v': 'v', 'b': 'b', 'n': 'p', 'm': 'm', ',': ',', '.': '.', '/': '/'}
# Total cost: 875,997.01
# Total presses: 999,998.0
#   the_algorithms_code: 875997.0113700507
# processing dataset gutenberg
# {'q': 'q', 'w': 'w', 'e': 'd', 'r': 'f', 't': 'k', 'y': 'j', 'u': 'u', 'i': 'r', 'o': 'l', 'p': ';', '[': '[', ']': ']', '\\': '\\', 'a': 'a', 's': 's', 'd': 'e', 'f': 't', 'g': 'g', 'h': 'y', 'j': 'n', 'k': 'i', 'l': 'o', ';': 'h', "'": "'", 'z': 'z', 'x': 'x', 'c': 'c', 'v': 'v', 'b': 'b', 'n': 'p', 'm': 'm', ',': ',', '.': '.', '/': '/'}
# Total cost: 584,892.80
# Total presses: 999,998.0
#   gutenberg: 584892.8025087768
# processing dataset cartigratis
#   Skipping blacklisted dataset: cartigratis
# processing dataset newsgroup
# {'q': 'q', 'w': 'w', 'e': 'd', 'r': 'f', 't': 'k', 'y': 'j', 'u': 'u', 'i': 'r', 'o': 'l', 'p': ';', '[': '[', ']': ']', '\\': '\\', 'a': 'a', 's': 's', 'd': 'e', 'f': 't', 'g': 'g', 'h': 'y', 'j': 'n', 'k': 'i', 'l': 'o', ';': 'h', "'": "'", 'z': 'z', 'x': 'x', 'c': 'c', 'v': 'v', 'b': 'b', 'n': 'p', 'm': 'm', ',': ',', '.': '.', '/': '/'}
# Total cost: 836,255.02
# Total presses: 999,998.0
#   newsgroup: 836255.020759664
# Processing layout: asset
# processing dataset simple_wikipedia
# {'q': 'q', 'w': 'w', 'e': 'j', 'r': 'f', 't': 'g', 'y': 'y', 'u': 'p', 'i': 'u', 'o': 'l', 'p': ';', '[': '[', ']': ']', '\\': '\\', 'a': 'a', 's': 's', 'd': 'e', 'f': 't', 'g': 'd', 'h': 'h', 'j': 'n', 'k': 'i', 'l': 'o', ';': 'r', "'": "'", 'z': 'z', 'x': 'x', 'c': 'c', 'v': 'v', 'b': 'b', 'n': 'k', 'm': 'm', ',': ',', '.': '.', '/': '/'}
# Total cost: 628,649.70
# Total presses: 1,000,003.0
#   simple_wikipedia: 628649.701997203
# processing dataset the_algorithms_code
# {'q': 'q', 'w': 'w', 'e': 'j', 'r': 'f', 't': 'g', 'y': 'y', 'u': 'p', 'i': 'u', 'o': 'l', 'p': ';', '[': '[', ']': ']', '\\': '\\', 'a': 'a', 's': 's', 'd': 'e', 'f': 't', 'g': 'd', 'h': 'h', 'j': 'n', 'k': 'i', 'l': 'o', ';': 'r', "'": "'", 'z': 'z', 'x': 'x', 'c': 'c', 'v': 'v', 'b': 'b', 'n': 'k', 'm': 'm', ',': ',', '.': '.', '/': '/'}
# Total cost: 886,634.23
# Total presses: 999,998.0
#   the_algorithms_code: 886634.2303419189
# processing dataset gutenberg
# {'q': 'q', 'w': 'w', 'e': 'j', 'r': 'f', 't': 'g', 'y': 'y', 'u': 'p', 'i': 'u', 'o': 'l', 'p': ';', '[': '[', ']': ']', '\\': '\\', 'a': 'a', 's': 's', 'd': 'e', 'f': 't', 'g': 'd', 'h': 'h', 'j': 'n', 'k': 'i', 'l': 'o', ';': 'r', "'": "'", 'z': 'z', 'x': 'x', 'c': 'c', 'v': 'v', 'b': 'b', 'n': 'k', 'm': 'm', ',': ',', '.': '.', '/': '/'}
# Total cost: 577,847.65
# Total presses: 999,998.0
#   gutenberg: 577847.6452341462
# processing dataset cartigratis
#   Skipping blacklisted dataset: cartigratis
# processing dataset newsgroup
# {'q': 'q', 'w': 'w', 'e': 'j', 'r': 'f', 't': 'g', 'y': 'y', 'u': 'p', 'i': 'u', 'o': 'l', 'p': ';', '[': '[', ']': ']', '\\': '\\', 'a': 'a', 's': 's', 'd': 'e', 'f': 't', 'g': 'd', 'h': 'h', 'j': 'n', 'k': 'i', 'l': 'o', ';': 'r', "'": "'", 'z': 'z', 'x': 'x', 'c': 'c', 'v': 'v', 'b': 'b', 'n': 'k', 'm': 'm', ',': ',', '.': '.', '/': '/'}
# Total cost: 838,736.41
# Total presses: 999,998.0
#   newsgroup: 838736.4135732495
# Processing layout: colemak
# processing dataset simple_wikipedia
# {'q': 'q', 'w': 'w', 'e': 'f', 'r': 'p', 't': 'g', 'y': 'j', 'u': 'l', 'i': 'u', 'o': 'y', 'p': ';', '[': '[', ']': ']', '\\': '\\', 'a': 'a', 's': 'r', 'd': 's', 'f': 't', 'g': 'd', 'h': 'h', 'j': 'n', 'k': 'e', 'l': 'i', ';': 'o', "'": "'", 'z': 'z', 'x': 'x', 'c': 'c', 'v': 'v', 'b': 'b', 'n': 'k', 'm': 'm', ',': ',', '.': '.', '/': '/'}
# Total cost: 753,241.55
# Total presses: 1,000,003.0
#   simple_wikipedia: 753241.5521737146
# processing dataset the_algorithms_code
# {'q': 'q', 'w': 'w', 'e': 'f', 'r': 'p', 't': 'g', 'y': 'j', 'u': 'l', 'i': 'u', 'o': 'y', 'p': ';', '[': '[', ']': ']', '\\': '\\', 'a': 'a', 's': 'r', 'd': 's', 'f': 't', 'g': 'd', 'h': 'h', 'j': 'n', 'k': 'e', 'l': 'i', ';': 'o', "'": "'", 'z': 'z', 'x': 'x', 'c': 'c', 'v': 'v', 'b': 'b', 'n': 'k', 'm': 'm', ',': ',', '.': '.', '/': '/'}
# Total cost: 963,499.19
# Total presses: 999,998.0
#   the_algorithms_code: 963499.1872911819
# processing dataset gutenberg
# {'q': 'q', 'w': 'w', 'e': 'f', 'r': 'p', 't': 'g', 'y': 'j', 'u': 'l', 'i': 'u', 'o': 'y', 'p': ';', '[': '[', ']': ']', '\\': '\\', 'a': 'a', 's': 'r', 'd': 's', 'f': 't', 'g': 'd', 'h': 'h', 'j': 'n', 'k': 'e', 'l': 'i', ';': 'o', "'": "'", 'z': 'z', 'x': 'x', 'c': 'c', 'v': 'v', 'b': 'b', 'n': 'k', 'm': 'm', ',': ',', '.': '.', '/': '/'}
# Total cost: 690,755.33
# Total presses: 999,998.0
#   gutenberg: 690755.3269770315
# processing dataset cartigratis
#   Skipping blacklisted dataset: cartigratis
# processing dataset newsgroup
# {'q': 'q', 'w': 'w', 'e': 'f', 'r': 'p', 't': 'g', 'y': 'j', 'u': 'l', 'i': 'u', 'o': 'y', 'p': ';', '[': '[', ']': ']', '\\': '\\', 'a': 'a', 's': 'r', 'd': 's', 'f': 't', 'g': 'd', 'h': 'h', 'j': 'n', 'k': 'e', 'l': 'i', ';': 'o', "'": "'", 'z': 'z', 'x': 'x', 'c': 'c', 'v': 'v', 'b': 'b', 'n': 'k', 'm': 'm', ',': ',', '.': '.', '/': '/'}
# Total cost: 938,837.90
# Total presses: 999,998.0
#   newsgroup: 938837.9047820012

# %%
with open('kle_keyboards/dactyl_manuform_6x6_4_hands.json', 'r') as f:
    keyboard = Serial.parse(f.read())

keyboard = KeyboardPhenotype(keyboard, {})

# keyboard.select_remap_keys(LAYOUT_DATA['qwerty'])
# keyboard.remap_to_keys(LAYOUT_DATA['asset'])
keyboard.fitness(data['simple_wikipedia'])
show_keyboard(keyboard.get_phisical_keyboard())
# Out:
# Init keyboard phenotype
# Key is unneeded ('F1',)
# Key is unneeded ('F2',)
# Key is unneeded ('F3',)
# Key is unneeded ('F4',)
# Key is unneeded ('F5',)
# Key is unneeded ('F6',)
# Key is unneeded ('F7',)
# Key is unneeded ('F8',)
# Key is unneeded ('F9',)
# Key is unneeded ('F10',)
# Key is unneeded ('F11',)
# Key is unneeded ('F12',)
# Key is unneeded ('Esc',)
# Key is unneeded ('Backspace',)
# Key is unneeded ('Ctrl',)
# Key is unneeded (None,)
# Key is unneeded (None,)
# Key is unneeded (None,)
# Key is unneeded (None,)
# Key is unneeded (None,)
# Key is unneeded (None,)
# Key is unneeded ('Home',)
# Key is unneeded ('Delete',)
# Key is unneeded ('Ctrl',)
# Key is unneeded ('Win',)
# Key is unneeded ('Ctrl',)
# Total cost: 865,337.60
# Total presses: 1,000,003.0

# %%
show_keyboard(keyboard.get_physical_keyboard_with_costs())

# %%
keyboard.select_remap_keys(LAYOUT_DATA['qwerty'])
keyboard.remap_to_keys(LAYOUT_DATA['asset'])
keyboard.fitness(data['simple_wikipedia'])
show_keyboard(keyboard.get_phisical_keyboard())
# Out:
# {'q': 'q', 'w': 'w', 'e': 'j', 'r': 'f', 't': 'g', 'y': 'y', 'u': 'p', 'i': 'u', 'o': 'l', 'p': ';', '[': '[', ']': ']', '\\': '\\', 'a': 'a', 's': 's', 'd': 'e', 'f': 't', 'g': 'd', 'h': 'h', 'j': 'n', 'k': 'i', 'l': 'o', ';': 'r', "'": "'", 'z': 'z', 'x': 'x', 'c': 'c', 'v': 'v', 'b': 'b', 'n': 'k', 'm': 'm', ',': ',', '.': '.', '/': '/'}
# Total cost: 626,153.76
# Total presses: 1,000,003.0
