# %%
import os
import pickle
from keyboard_phenotype import KeyboardPhenotype
from kle.kle_model import Serial, FingerName
from keyboard_genotypes import LAYOUT_DATA
from kle.kle_renderer import show_keyboard, render_keyboard

try:
    data_file = './processed/markov_chains.pkl'
    if not os.path.exists(data_file):
        print(f"ERROR: Data file not found: {data_file}")
        data = {}
    else:
        with open(data_file, 'rb') as f:
            data = pickle.load(f)
        print(f"✅ Successfully loaded data from {data_file}")
except Exception as e:
    print(f"ERROR loading data: {e}")
    data = {}
# Out:
# Original COST_PER_FINGER:
# {<FingerName.LEFT_PINKY: 0>: 3.7553795350190766, <FingerName.LEFT_RING: 1>: 3.696016650469711, <FingerName.LEFT_MIDDLE: 2>: 3.5198745273779157, <FingerName.LEFT_INDEX: 3>: 2.434926735493057, <FingerName.LEFT_THUMB: 4>: 1.0, <FingerName.RIGHT_THUMB: 5>: 1.0, <FingerName.RIGHT_INDEX: 6>: 2.434926735493057, <FingerName.RIGHT_MIDDLE: 7>: 3.5198745273779157, <FingerName.RIGHT_RING: 8>: 3.696016650469711, <FingerName.RIGHT_PINKY: 9>: 3.7553795350190766}
#
# Scaled COST_PER_FINGER (1 to 1.5):
# {<FingerName.LEFT_PINKY: 0>: 1.5, <FingerName.LEFT_RING: 1>: 1.4892278207421334, <FingerName.LEFT_MIDDLE: 2>: 1.45726450664091, <FingerName.LEFT_INDEX: 3>: 1.260386403625358, <FingerName.LEFT_THUMB: 4>: 1.0, <FingerName.RIGHT_THUMB: 5>: 1.0, <FingerName.RIGHT_INDEX: 6>: 1.260386403625358, <FingerName.RIGHT_MIDDLE: 7>: 1.45726450664091, <FingerName.RIGHT_RING: 8>: 1.4892278207421334, <FingerName.RIGHT_PINKY: 9>: 1.5}
#
# Min value: 1.0
# Max value: 1.5
# ✅ Successfully loaded data from ./processed/markov_chains.pkl

# %%
with open('kle_keyboards/ansi_60_percent_hands.json', 'r') as f:
    keyboard = Serial.parse(f.read())

keyboard = KeyboardPhenotype(keyboard, {})


keyboard.select_remap_keys(LAYOUT_DATA['qwerty'])
# keyboard.remap_to_keys(LAYOUT_DATA['asset'])
keyboard.fitness(data['simple_wikipedia'])
show_keyboard(keyboard.get_phisical_keyboard())
# Out:
# Init keyboard phenotype
# Key is unneeded ('Backspace',)
# Key is unneeded ('Caps Lock',)
# Key is unneeded ('Ctrl',)
# Key is unneeded ('Win',)
# Key is unneeded ('Alt',)
# Key is unneeded ('Win',)
# Key is unneeded ('Menu',)
# Key is unneeded ('Ctrl',)
# Level 1&2 branches: 7,591
# Remaining budget for level 3+: 4,992,409
# Total cost: 1,202,288.91
# Total presses: 1,000,003.0
# Paths explored: 96
# Total branches used: 96
# Level 3+ branches used: 0
# Branch budget utilization: 0.0%

# %%
show_keyboard(keyboard.get_physical_keyboard_with_costs())

# %%
import matplotlib.pyplot as plt

# Collect fitness values
fitness_values = []
layout_keys = []

for key, value in LAYOUT_DATA.items():
    print(key)
    keyboard.remap_to_keys(value)
    fitness = keyboard.fitness(data['simple_wikipedia'])  # Store the returned fitness value
    fitness_values.append(fitness)
    layout_keys.append(key)
    show_keyboard(keyboard.get_phisical_keyboard())
# Out:
# qwerty
# {'q': 'q', 'w': 'w', 'e': 'e', 'r': 'r', 't': 't', 'y': 'y', 'u': 'u', 'i': 'i', 'o': 'o', 'p': 'p', '[': '[', ']': ']', '\\': '\\', 'a': 'a', 's': 's', 'd': 'd', 'f': 'f', 'g': 'g', 'h': 'h', 'j': 'j', 'k': 'k', 'l': 'l', ';': ';', "'": "'", 'z': 'z', 'x': 'x', 'c': 'c', 'v': 'v', 'b': 'b', 'n': 'n', 'm': 'm', ',': ',', '.': '.', '/': '/'}
# Level 1&2 branches: 7,591
# Remaining budget for level 3+: 4,992,409
# Total cost: 1,202,288.91
# Total presses: 1,000,003.0
# Paths explored: 96
# Total branches used: 96
# Level 3+ branches used: 0
# Branch budget utilization: 0.0%
# minimak
# {'q': 'q', 'w': 'w', 'e': 'd', 'r': 'f', 't': 'k', 'y': 'y', 'u': 'u', 'i': 'i', 'o': 'l', 'p': ';', '[': '[', ']': ']', '\\': '\\', 'a': 'a', 's': 's', 'd': 't', 'f': 'r', 'g': 'g', 'h': 'h', 'j': 'n', 'k': 'e', 'l': 'o', ';': 'p', "'": "'", 'z': 'z', 'x': 'x', 'c': 'c', 'v': 'v', 'b': 'b', 'n': 'j', 'm': 'm', ',': ',', '.': '.', '/': '/'}
# Level 1&2 branches: 7,591
# Remaining budget for level 3+: 4,992,409
# Total cost: 828,440.48
# Total presses: 1,000,003.0
# Paths explored: 96
# Total branches used: 96
# Level 3+ branches used: 0
# Branch budget utilization: 0.0%
# dvorak
# {'q': "'", 'w': ',', 'e': '.', 'r': 'p', 't': 'y', 'y': 'f', 'u': 'g', 'i': 'c', 'o': 'r', 'p': 'l', '[': '/', ']': '=', '\\': '\\', 'a': 'a', 's': 'o', 'd': 'e', 'f': 'u', 'g': 'i', 'h': 'd', 'j': 'h', 'k': 't', 'l': 'n', ';': 's', "'": '-', 'z': ';', 'x': 'q', 'c': 'j', 'v': 'k', 'b': 'x', 'n': 'b', 'm': 'm', ',': 'w', '.': 'v', '/': 'z'}
# Level 1&2 branches: 7,591
# Remaining budget for level 3+: 4,992,409
# Total cost: 1,344,070.80
# Total presses: 1,000,003.0
# Paths explored: 96
# Total branches used: 96
# Level 3+ branches used: 0
# Branch budget utilization: 0.0%
# workman
# {'q': 'q', 'w': 'd', 'e': 'r', 'r': 'w', 't': 'b', 'y': 'j', 'u': 'f', 'i': 'u', 'o': 'p', 'p': ';', '[': '[', ']': ']', '\\': '\\', 'a': 'a', 's': 's', 'd': 'h', 'f': 't', 'g': 'g', 'h': 'y', 'j': 'n', 'k': 'e', 'l': 'o', ';': 'i', "'": "'", 'z': 'z', 'x': 'x', 'c': 'm', 'v': 'c', 'b': 'v', 'n': 'k', 'm': 'l', ',': ',', '.': '.', '/': '/'}
# Level 1&2 branches: 7,591
# Remaining budget for level 3+: 4,992,409
# Total cost: 1,157,049.70
# Total presses: 1,000,003.0
# Paths explored: 96
# Total branches used: 96
# Level 3+ branches used: 0
# Branch budget utilization: 0.0%
# norman
# {'q': 'q', 'w': 'w', 'e': 'd', 'r': 'f', 't': 'k', 'y': 'j', 'u': 'u', 'i': 'r', 'o': 'l', 'p': ';', '[': '[', ']': ']', '\\': '\\', 'a': 'a', 's': 's', 'd': 'e', 'f': 't', 'g': 'g', 'h': 'y', 'j': 'n', 'k': 'i', 'l': 'o', ';': 'h', "'": "'", 'z': 'z', 'x': 'x', 'c': 'c', 'v': 'v', 'b': 'b', 'n': 'p', 'm': 'm', ',': ',', '.': '.', '/': '/'}
# Level 1&2 branches: 7,591
# Remaining budget for level 3+: 4,992,409
# Total cost: 913,594.07
# Total presses: 1,000,003.0
# Paths explored: 96
# Total branches used: 96
# Level 3+ branches used: 0
# Branch budget utilization: 0.0%
# asset
# {'q': 'q', 'w': 'w', 'e': 'j', 'r': 'f', 't': 'g', 'y': 'y', 'u': 'p', 'i': 'u', 'o': 'l', 'p': ';', '[': '[', ']': ']', '\\': '\\', 'a': 'a', 's': 's', 'd': 'e', 'f': 't', 'g': 'd', 'h': 'h', 'j': 'n', 'k': 'i', 'l': 'o', ';': 'r', "'": "'", 'z': 'z', 'x': 'x', 'c': 'c', 'v': 'v', 'b': 'b', 'n': 'k', 'm': 'm', ',': ',', '.': '.', '/': '/'}
# Level 1&2 branches: 7,591
# Remaining budget for level 3+: 4,992,409
# Total cost: 893,187.69
# Total presses: 1,000,003.0
# Paths explored: 96
# Total branches used: 96
# Level 3+ branches used: 0
# Branch budget utilization: 0.0%
# colemak
# {'q': 'q', 'w': 'w', 'e': 'f', 'r': 'p', 't': 'g', 'y': 'j', 'u': 'l', 'i': 'u', 'o': 'y', 'p': ';', '[': '[', ']': ']', '\\': '\\', 'a': 'a', 's': 'r', 'd': 's', 'f': 't', 'g': 'd', 'h': 'h', 'j': 'n', 'k': 'e', 'l': 'i', ';': 'o', "'": "'", 'z': 'z', 'x': 'x', 'c': 'c', 'v': 'v', 'b': 'b', 'n': 'k', 'm': 'm', ',': ',', '.': '.', '/': '/'}
# Level 1&2 branches: 7,591
# Remaining budget for level 3+: 4,992,409
# Total cost: 1,053,857.87
# Total presses: 1,000,003.0
# Paths explored: 96
# Total branches used: 96
# Level 3+ branches used: 0
# Branch budget utilization: 0.0%

# %%
import matplotlib.pyplot as plt
from collections import defaultdict
from concurrent.futures import ProcessPoolExecutor, as_completed
import copy
import multiprocessing as mp
from kle.kle_model import Keyboard, FingerName, Hand
from keyboard_phenotype import KeyboardPhenotype
import pickle

# Configuration - use actual CPU count for optimal performance
NUM_PROCESSES = mp.cpu_count()  # This will use all available CPU cores
print(f"Using {NUM_PROCESSES} processes for parallel evaluation")

# Blacklist specific dataset
BLACKLISTED_DATASET = ['cartigratis']
DATASETS = data

def combine_datasets(datasets, blacklisted_datasets=None):
    """
    Combine multiple datasets into a single averaged dataset
    """
    if blacklisted_datasets is None:
        blacklisted_datasets = []
    
    # Filter out blacklisted datasets
    filtered_datasets = {k: v for k, v in datasets.items() 
                        if k not in blacklisted_datasets}
    
    if not filtered_datasets:
        raise ValueError("No datasets available after filtering")
    
    # Initialize combined dataset structure
    combined_markov_chain = defaultdict(lambda: {
        'count': 0,
        'global_percentage': 0.0,
        'category_percentage': 0.0,
        'category': '',
        'next': defaultdict(lambda: {'count': 0, 'percentage': 0.0})
    })
    
    # Sum up all datasets
    dataset_count = len(filtered_datasets)
    
    for dataset_name, dataset_data in filtered_datasets.items():
        markov_data = dataset_data['markov_chain']
        
        for key, key_data in markov_data.items():
            # Average the main key statistics
            combined_markov_chain[key]['count'] += key_data.get('count', 0)
            combined_markov_chain[key]['global_percentage'] += key_data.get('global_percentage', 0.0)
            combined_markov_chain[key]['category_percentage'] += key_data.get('category_percentage', 0.0)
            
            # Take category from first occurrence (they should be the same)
            if not combined_markov_chain[key]['category']:
                combined_markov_chain[key]['category'] = key_data.get('category', '')
            
            # Sum up the 'next' transitions
            if 'next' in key_data:
                for next_key, next_data in key_data['next'].items():
                    combined_markov_chain[key]['next'][next_key]['count'] += next_data.get('count', 0)
                    combined_markov_chain[key]['next'][next_key]['percentage'] += next_data.get('percentage', 0.0)
    
    # Average the values
    for key, key_data in combined_markov_chain.items():
        key_data['global_percentage'] /= dataset_count
        key_data['category_percentage'] /= dataset_count
        
        # Average the 'next' percentages
        for next_key, next_data in key_data['next'].items():
            next_data['percentage'] /= dataset_count
    
    # Convert defaultdict back to regular dict for consistency
    final_combined = {}
    for key, key_data in combined_markov_chain.items():
        final_combined[key] = {
            'count': key_data['count'],
            'global_percentage': key_data['global_percentage'],
            'category_percentage': key_data['category_percentage'],
            'category': key_data['category'],
            'next': dict(key_data['next'])
        }
    
    return {'markov_chain': final_combined}

def evaluate_single_layout_process(args):
    """
    Evaluate a single layout in a separate process.
    Takes a tuple of arguments for multiprocessing compatibility.
    """
    layout_key, layout_value, base_keyboard_data, combined_dataset, qwerty_layout, depth = args
    
    try:
        # Create a fresh keyboard phenotype for this process
        thread_keyboard = KeyboardPhenotype(base_keyboard_data, {})
        thread_keyboard.select_remap_keys(qwerty_layout)
        thread_keyboard.remap_to_keys(layout_value)
        
        print(f"Process evaluating layout: {layout_key}")
        fitness = thread_keyboard.fitness(combined_dataset, depth=depth)
        
        return layout_key, fitness
        
    except Exception as e:
        print(f"Error evaluating layout {layout_key}: {str(e)}")
        return layout_key, float('inf')  # Return infinite fitness for failed layouts

def create_layout_batches(layout_items, num_processes):
    """
    Create balanced batches of layouts for each process to minimize idle time.
    """
    # Sort layouts by estimated complexity (you could use layout name length as a simple heuristic)
    # For now, just distribute evenly
    batch_size = len(layout_items) // num_processes + 1
    batches = []
    
    for i in range(0, len(layout_items), batch_size):
        batch = layout_items[i:i + batch_size]
        if batch:  # Only add non-empty batches
            batches.append(batch)
    
    return batches

def evaluate_layout_batch(args):
    """
    Evaluate multiple layouts in a single process to reduce process creation overhead.
    """
    batch, base_keyboard_data, combined_dataset, qwerty_layout, depth = args
    
    results = []
    for layout_key, layout_value in batch:
        try:
            # Create a fresh keyboard phenotype for this layout
            thread_keyboard = KeyboardPhenotype(base_keyboard_data, {})
            thread_keyboard.select_remap_keys(qwerty_layout)
            thread_keyboard.remap_to_keys(layout_value)
            
            print(f"Process evaluating layout: {layout_key}")
            fitness = thread_keyboard.fitness(combined_dataset, depth=depth)
            results.append((layout_key, fitness))
            
        except Exception as e:
            print(f"Error evaluating layout {layout_key}: {str(e)}")
            results.append((layout_key, float('inf')))
    
    return results

if __name__ == '__main__':
    # Combine all datasets (except blacklisted) into one averaged dataset
    print("Combining datasets...")
    combined_dataset = combine_datasets(DATASETS, BLACKLISTED_DATASET)
    print(f"Combined {len([k for k in DATASETS.keys() if k not in BLACKLISTED_DATASET])} datasets")

    # Load the base keyboard once
    with open('kle_keyboards/ansi_60_percent_hands.json', 'r') as f:
        base_keyboard_raw = Serial.parse(f.read())

    # Collect fitness values for all layouts using parallel processing
    results = {}
    layout_fitness_values = []
    layout_names = []

    print("Evaluating layouts in parallel using multiprocessing...")

    # Convert LAYOUT_DATA to list of items for parallel processing
    layout_items = list(LAYOUT_DATA.items())
    print(f"Total layouts to evaluate: {len(layout_items)}")

    # Create batches for more efficient processing
    layout_batches = create_layout_batches(layout_items, NUM_PROCESSES)
    print(f"Created {len(layout_batches)} batches for {NUM_PROCESSES} processes")

    # Prepare arguments for each batch
    batch_args = [
        (batch, base_keyboard_raw, combined_dataset, LAYOUT_DATA['qwerty'], 8)
        for batch in layout_batches
    ]

    # Process layouts in parallel using separate processes
    with ProcessPoolExecutor(max_workers=NUM_PROCESSES) as executor:
        # Submit batch evaluation tasks
        future_to_batch = {
            executor.submit(evaluate_layout_batch, batch_arg): i 
            for i, batch_arg in enumerate(batch_args)
        }
        
        # Collect results as they complete
        for future in as_completed(future_to_batch):
            try:
                batch_results = future.result()
                for layout_key, fitness in batch_results:
                    results[layout_key] = fitness
                    layout_fitness_values.append(fitness)
                    layout_names.append(layout_key)
                    print(f"Completed: {layout_key} -> {fitness:,.2f}")
                    
            except Exception as exc:
                batch_id = future_to_batch[future]
                print(f"Batch {batch_id} generated an exception: {exc}")

    # Sort layouts by fitness (increasing order - lower is better)
    sorted_data = sorted(zip(layout_names, layout_fitness_values), key=lambda x: x[1])
    sorted_layouts, sorted_fitness_values = zip(*sorted_data)

    # Create bar chart
    plt.figure(figsize=(12, 6))
    bars = plt.bar(sorted_layouts, sorted_fitness_values)

    # Color the bars - best layout in green, worst in red, others in blue
    if len(bars) > 0:
        bars[0].set_color('green')  # Best (lowest fitness)
        if len(bars) > 1:
            bars[-1].set_color('red')   # Worst (highest fitness)
        for bar in bars[1:-1]:
            bar.set_color('blue')

    plt.xlabel('Layout')
    plt.ylabel('Fitness Value (Combined Datasets)')
    plt.title('Fitness Values for Different Layouts (Combined Dataset Average)')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()

    # Add value labels on bars
    for i, (layout, fitness) in enumerate(zip(sorted_layouts, sorted_fitness_values)):
        plt.text(i, fitness + max(sorted_fitness_values) * 0.01, 
                 f'{fitness:,.0f}', ha='center', va='bottom', fontsize=8)

    plt.show()

    # Print results summary
    print("\n" + "="*50)
    print("RESULTS SUMMARY")
    print("="*50)
    for i, (layout, fitness) in enumerate(zip(sorted_layouts, sorted_fitness_values)):
        rank = i + 1
        print(f"{rank:2d}. {layout:15s}: {fitness:12,.2f}")
    print("="*50)
# Out:
# Using 16 processes for parallel evaluation
# Combining datasets...
# Combined 4 datasets
# Evaluating layouts in parallel using multiprocessing...
# Total layouts to evaluate: 7
# Created 7 batches for 16 processes
# Init keyboard phenotype
# Init keyboard phenotypeKey is unneeded ('Backspace',)
#
# Init keyboard phenotypeKey is unneeded ('Caps Lock',)
#
# Key is unneeded ('Backspace',)
# Init keyboard phenotypeKey is unneeded ('Backspace',)Key is unneeded ('Ctrl',)
#
#
# Key is unneeded ('Caps Lock',)
# Key is unneeded ('Win',)Key is unneeded ('Caps Lock',)Key is unneeded ('Backspace',)
#
# Key is unneeded ('Ctrl',)Init keyboard phenotype
# Key is unneeded ('Alt',)
#
#
# Key is unneeded ('Ctrl',)Key is unneeded ('Win',)Key is unneeded ('Caps Lock',)Init keyboard phenotypeKey is unneeded ('Win',)
#
#
# Key is unneeded ('Backspace',)
#
# Key is unneeded ('Win',)Key is unneeded ('Alt',)
# Key is unneeded ('Menu',)
# Key is unneeded ('Ctrl',)
#
#
# Key is unneeded ('Alt',)Key is unneeded ('Win',)Key is unneeded ('Ctrl',)Key is unneeded ('Backspace',)Key is unneeded ('Caps Lock',)Init keyboard phenotype
#
# Key is unneeded ('Win',)
#
#
# Key is unneeded ('Menu',)
#
# Key is unneeded ('Win',){'q': 'q', 'w': 'w', 'e': 'e', 'r': 'r', 't': 't', 'y': 'y', 'u': 'u', 'i': 'i', 'o': 'o', 'p': 'p', '[': '[', ']': ']', '\\': '\\', 'a': 'a', 's': 's', 'd': 'd', 'f': 'f', 'g': 'g', 'h': 'h', 'j': 'j', 'k': 'k', 'l': 'l', ';': ';', "'": "'", 'z': 'z', 'x': 'x', 'c': 'c', 'v': 'v', 'b': 'b', 'n': 'n', 'm': 'm', ',': ',', '.': '.', '/': '/'}
# Key is unneeded ('Caps Lock',)
#
# Key is unneeded ('Ctrl',)Key is unneeded ('Ctrl',)
# Key is unneeded ('Menu',)Process evaluating layout: qwertyKey is unneeded ('Backspace',)
#
#
#
#
# {'q': 'q', 'w': 'w', 'e': 'd', 'r': 'f', 't': 'k', 'y': 'y', 'u': 'u', 'i': 'i', 'o': 'l', 'p': ';', '[': '[', ']': ']', '\\': '\\', 'a': 'a', 's': 's', 'd': 't', 'f': 'r', 'g': 'g', 'h': 'h', 'j': 'n', 'k': 'e', 'l': 'o', ';': 'p', "'": "'", 'z': 'z', 'x': 'x', 'c': 'c', 'v': 'v', 'b': 'b', 'n': 'j', 'm': 'm', ',': ',', '.': '.', '/': '/'}Key is unneeded ('Win',)Key is unneeded ('Ctrl',)Key is unneeded ('Ctrl',)Key is unneeded ('Alt',)
#
# Key is unneeded ('Caps Lock',)
#
#
# Level 1&2 branches: 9,429Process evaluating layout: minimakKey is unneeded ('Alt',)
# Key is unneeded ('Win',){'q': "'", 'w': ',', 'e': '.', 'r': 'p', 't': 'y', 'y': 'f', 'u': 'g', 'i': 'c', 'o': 'r', 'p': 'l', '[': '/', ']': '=', '\\': '\\', 'a': 'a', 's': 'o', 'd': 'e', 'f': 'u', 'g': 'i', 'h': 'd', 'j': 'h', 'k': 't', 'l': 'n', ';': 's', "'": '-', 'z': ';', 'x': 'q', 'c': 'j', 'v': 'k', 'b': 'x', 'n': 'b', 'm': 'm', ',': 'w', '.': 'v', '/': 'z'}
# Key is unneeded ('Win',)
#
#
#
# Remaining budget for level 3+: 4,990,571Key is unneeded ('Ctrl',)
# Key is unneeded ('Win',)Key is unneeded ('Alt',)Process evaluating layout: dvorakKey is unneeded ('Menu',)
#
#
# Level 1&2 branches: 9,429
#
# Key is unneeded ('Win',)
# Key is unneeded ('Menu',)
#
# Key is unneeded ('Win',)Level 1&2 branches: 9,429
# Key is unneeded ('Ctrl',)
#
# Remaining budget for level 3+: 4,990,571Key is unneeded ('Menu',)Key is unneeded ('Ctrl',)
# Key is unneeded ('Alt',)Remaining budget for level 3+: 4,990,571
#
#
# {'q': 'q', 'w': 'd', 'e': 'r', 'r': 'w', 't': 'b', 'y': 'j', 'u': 'f', 'i': 'u', 'o': 'p', 'p': ';', '[': '[', ']': ']', '\\': '\\', 'a': 'a', 's': 's', 'd': 'h', 'f': 't', 'g': 'g', 'h': 'y', 'j': 'n', 'k': 'e', 'l': 'o', ';': 'i', "'": "'", 'z': 'z', 'x': 'x', 'c': 'm', 'v': 'c', 'b': 'v', 'n': 'k', 'm': 'l', ',': ',', '.': '.', '/': '/'}
#
# {'q': 'q', 'w': 'w', 'e': 'd', 'r': 'f', 't': 'k', 'y': 'j', 'u': 'u', 'i': 'r', 'o': 'l', 'p': ';', '[': '[', ']': ']', '\\': '\\', 'a': 'a', 's': 's', 'd': 'e', 'f': 't', 'g': 'g', 'h': 'y', 'j': 'n', 'k': 'i', 'l': 'o', ';': 'h', "'": "'", 'z': 'z', 'x': 'x', 'c': 'c', 'v': 'v', 'b': 'b', 'n': 'p', 'm': 'm', ',': ',', '.': '.', '/': '/'}Key is unneeded ('Ctrl',)
# Key is unneeded ('Win',)
#
# Process evaluating layout: workmanProcess evaluating layout: norman
# Key is unneeded ('Menu',)
#
#
# Key is unneeded ('Ctrl',)Level 1&2 branches: 9,429Level 1&2 branches: 9,429{'q': 'q', 'w': 'w', 'e': 'j', 'r': 'f', 't': 'g', 'y': 'y', 'u': 'p', 'i': 'u', 'o': 'l', 'p': ';', '[': '[', ']': ']', '\\': '\\', 'a': 'a', 's': 's', 'd': 'e', 'f': 't', 'g': 'd', 'h': 'h', 'j': 'n', 'k': 'i', 'l': 'o', ';': 'r', "'": "'", 'z': 'z', 'x': 'x', 'c': 'c', 'v': 'v', 'b': 'b', 'n': 'k', 'm': 'm', ',': ',', '.': '.', '/': '/'}
#
#
#
# {'q': 'q', 'w': 'w', 'e': 'f', 'r': 'p', 't': 'g', 'y': 'j', 'u': 'l', 'i': 'u', 'o': 'y', 'p': ';', '[': '[', ']': ']', '\\': '\\', 'a': 'a', 's': 'r', 'd': 's', 'f': 't', 'g': 'd', 'h': 'h', 'j': 'n', 'k': 'e', 'l': 'i', ';': 'o', "'": "'", 'z': 'z', 'x': 'x', 'c': 'c', 'v': 'v', 'b': 'b', 'n': 'k', 'm': 'm', ',': ',', '.': '.', '/': '/'}Remaining budget for level 3+: 4,990,571Remaining budget for level 3+: 4,990,571
# Process evaluating layout: colemak
#
#
# Process evaluating layout: assetLevel 1&2 branches: 9,429
#
# Remaining budget for level 3+: 4,990,571Level 1&2 branches: 9,429
#
# Remaining budget for level 3+: 4,990,571
# Total cost: 1.78
# Total presses: 0.8805358903774333
# Paths explored: 4,938,703
# Total branches used: 5,000,000
# Level 3+ branches used: 4,990,571
# Branch budget utilization: 100.0%
# Completed: workman -> 1.78
# Total cost: 1.43
# Total presses: 0.8805358902813613
# Paths explored: 4,938,703
# Total branches used: 5,000,000
# Level 3+ branches used: 4,990,571
# Branch budget utilization: 100.0%
# Completed: norman -> 1.43
# Total cost: 1.84
# Total presses: 0.8805358894158474
# Paths explored: 4,938,703
# Total branches used: 5,000,000
# Level 3+ branches used: 4,990,571
# Branch budget utilization: 100.0%
# Total cost: 1.41
# Total presses: 0.880535888408781
# Paths explored: 4,938,703
# Total branches used: 5,000,000
# Level 3+ branches used: 4,990,571
# Branch budget utilization: 100.0%
# Completed: qwerty -> 1.84
# Completed: minimak -> 1.41
# Total cost: 1.67
# Total presses: 0.8805358906241015
# Paths explored: 4,938,703
# Total branches used: 5,000,000
# Level 3+ branches used: 4,990,571
# Branch budget utilization: 100.0%
# Completed: colemak -> 1.67
# Total cost: 1.45
# Total presses: 0.8805358868558474
# Paths explored: 4,938,703
# Total branches used: 5,000,000
# Level 3+ branches used: 4,990,571
# Branch budget utilization: 100.0%
# Completed: asset -> 1.45
# Total cost: 1.78
# Total presses: 0.880535885154239
# Paths explored: 4,938,703
# Total branches used: 5,000,000
# Level 3+ branches used: 4,990,571
# Branch budget utilization: 100.0%
# Completed: dvorak -> 1.78
# ==================================================
# RESULTS SUMMARY
# ==================================================
#  1. minimak        :         1.41
#  2. norman         :         1.43
#  3. asset          :         1.45
#  4. colemak        :         1.67
#  5. workman        :         1.78
#  6. dvorak         :         1.78
#  7. qwerty         :         1.84
# ==================================================

# %%
with open('kle_keyboards/dactyl_manuform_6x6_4_hands.json', 'r') as f:
    keyboard = Serial.parse(f.read())

keyboard = KeyboardPhenotype(keyboard, {})

# keyboard.select_remap_keys(LAYOUT_DATA['qwerty'])
# keyboard.remap_to_keys(LAYOUT_DATA['asset'])
keyboard.fitness(data['simple_wikipedia'])
show_keyboard(keyboard.get_phisical_keyboard())
# Out:
# Init keyboard phenotype
# Key is unneeded ('F1',)
# Key is unneeded ('F2',)
# Key is unneeded ('F3',)
# Key is unneeded ('F4',)
# Key is unneeded ('F5',)
# Key is unneeded ('F6',)
# Key is unneeded ('F7',)
# Key is unneeded ('F8',)
# Key is unneeded ('F9',)
# Key is unneeded ('F10',)
# Key is unneeded ('F11',)
# Key is unneeded ('F12',)
# Key is unneeded ('Esc',)
# Key is unneeded ('Backspace',)
# Key is unneeded ('Ctrl',)
# Key is unneeded (None,)
# Key is unneeded (None,)
# Key is unneeded (None,)
# Key is unneeded (None,)
# Key is unneeded (None,)
# Key is unneeded (None,)
# Key is unneeded ('Home',)
# Key is unneeded ('Delete',)
# Key is unneeded ('Ctrl',)
# Key is unneeded ('Win',)
# Key is unneeded ('Ctrl',)
# Level 1&2 branches: 7,591
# Remaining budget for level 3+: 4,992,409
# Total cost: 1,145,670.46
# Total presses: 1,000,003.0
# Paths explored: 96
# Total branches used: 96
# Level 3+ branches used: 0
# Branch budget utilization: 0.0%

# %%
show_keyboard(keyboard.get_physical_keyboard_with_costs())

# %%
keyboard.select_remap_keys(LAYOUT_DATA['qwerty'])
keyboard.remap_to_keys(LAYOUT_DATA['asset'])
keyboard.fitness(data['simple_wikipedia'])
show_keyboard(keyboard.get_phisical_keyboard())
# Out:
# {'q': 'q', 'w': 'w', 'e': 'j', 'r': 'f', 't': 'g', 'y': 'y', 'u': 'p', 'i': 'u', 'o': 'l', 'p': ';', '[': '[', ']': ']', '\\': '\\', 'a': 'a', 's': 's', 'd': 'e', 'f': 't', 'g': 'd', 'h': 'h', 'j': 'n', 'k': 'i', 'l': 'o', ';': 'r', "'": "'", 'z': 'z', 'x': 'x', 'c': 'c', 'v': 'v', 'b': 'b', 'n': 'k', 'm': 'm', ',': ',', '.': '.', '/': '/'}
# Level 1&2 branches: 7,591
# Remaining budget for level 3+: 4,992,409
# Total cost: 816,258.31
# Total presses: 1,000,003.0
# Paths explored: 96
# Total branches used: 96
# Level 3+ branches used: 0
# Branch budget utilization: 0.0%
