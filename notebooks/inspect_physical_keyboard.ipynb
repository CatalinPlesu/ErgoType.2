# %%
import sys
sys.path.append('..')
from src.domain.keyboard import Key, Keyboard, KeyboardMetadata, Serial
from src.helpers.keyboards.renderer import show_keyboard, render_keyboard

# %%
with open('../src/data/keyboards/ansi_60_percent.json', 'r') as f:
    keyboard = Serial.parse(f.read())
show_keyboard(keyboard)

# %%
with open('../src/data/keyboards/dactyl_manuform_6x6_4.json', 'r') as f:
    keyboard = Serial.parse(f.read())
show_keyboard(keyboard)

# %%
with open('../src/data/keyboards/ferris_sweep.json', 'r') as f:
    keyboard = Serial.parse(f.read())
show_keyboard(keyboard)
