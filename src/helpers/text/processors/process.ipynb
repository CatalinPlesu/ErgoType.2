# %%
def print_allowed_characters(results):
    """Print allowed characters for all datasets in a clear format."""
    print("\n=== ALLOWED CHARACTERS SUMMARY ===")
    for dataset_name, data in results.items():
        config = data['config']
        
        print(f"\n{dataset_name.upper()}:")
        print(f"  Letters ({len(config['allowed_letters'])}): {config['allowed_letters']}")
        print(f"  Digits ({len(config['allowed_digits'])}): {config['allowed_digits']}")
        print(f"  Symbols ({len(config['allowed_symbols'])}): {config['allowed_symbols']}")
        print(f"  Total allowed: {config['total_whitelist_chars']} characters")

print_allowed_characters(results)
# Out:
# === ALLOWED CHARACTERS SUMMARY ===
#
# SIMPLE_WIKIPEDIA:
#   Letters (52): abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ
#   Digits (10): 0123456789
#   Symbols (35): !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
#
#   Total allowed: 97 characters
#
# THE_ALGORITHMS_CODE:
#   Letters (52): abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ
#   Digits (10): 0123456789
#   Symbols (35): !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
#
#   Total allowed: 97 characters
#
# GUTENBERG:
#   Letters (52): abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ
#   Digits (10): 0123456789
#   Symbols (35): !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
#
#   Total allowed: 97 characters
#
# CARTIGRATIS:
#   Letters (62): abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZăâîșțĂÂÎȘȚ
#   Digits (10): 0123456789
#   Symbols (35): !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
#
#   Total allowed: 107 characters
#
# NEWSGROUP:
#   Letters (52): abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ
#   Digits (10): 0123456789
#   Symbols (35): !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
#
#   Total allowed: 97 characters

# %%
import os
import pickle
import json
import string
import re
from collections import Counter, defaultdict
import sys
sys.path.append('..')
from config.config import TOP_N_WORDS

def is_valid_word(word, allowed_letters, min_length=2):
    """Check if a word is valid (contains only letters and meets minimum length)"""
    if len(word) < min_length:
        return False
    
    # Word should contain only allowed letters
    return all(char in allowed_letters for char in word)

def extract_words_from_text(text, allowed_letters):
    """Extract valid words from text using regex and validation"""
    # Create character class for regex from allowed letters
    # Escape special regex characters
    escaped_letters = re.escape(''.join(sorted(set(allowed_letters))))
    
    # Find sequences of allowed letters
    word_pattern = f'[{escaped_letters}]+'
    
    # Extract all letter sequences
    potential_words = re.findall(word_pattern, text, re.IGNORECASE)
    
    # Filter for valid words
    valid_words = []
    for word in potential_words:
        if is_valid_word(word, allowed_letters):
            valid_words.append(word.lower())  # Normalize to lowercase
    
    return valid_words

def calculate_remaining_character_pool(results, top_n_words=1000):
    """Calculate remaining character pool after typing top N words"""
    updated_results = {}
    
    for dataset_name, dataset_result in results.items():
        # Get the original character counter
        original_char_counter = Counter()
        for char, freq_data in dataset_result['character_frequencies'].items():
            original_char_counter[char] = freq_data['absolute']
        
        # Get top N words
        top_words = dataset_result['word_frequencies'][:top_n_words]
        
        # Calculate characters used in typing top N words
        characters_used = Counter()
        for word_data in top_words:
            word = word_data['word']
            word_count = word_data['absolute']  # How many times this word appears
            for char in word:
                characters_used[char] += word_count  # Each character typed as many times as the word appears
        
        # Calculate remaining character pool
        remaining_pool = Counter()
        for char, original_count in original_char_counter.items():
            used_count = characters_used.get(char, 0)
            remaining_count = original_count - used_count
            if remaining_count > 0:  # Only keep characters that still have occurrences
                remaining_pool[char] = remaining_count
        
        # Calculate new frequencies based on remaining pool
        total_remaining_chars = sum(remaining_pool.values())
        remaining_char_frequencies = {}
        
        for char, count in remaining_pool.items():
            relative_freq = count / total_remaining_chars if total_remaining_chars > 0 else 0
            remaining_char_frequencies[char] = {
                'absolute': count,
                'relative': relative_freq
            }
        
        # Create updated result with remaining pool
        updated_dataset_result = dataset_result.copy()
        updated_dataset_result[f'{top_n_words}_remaining_characters_pool'] = {
            'remaining_pool': dict(remaining_pool),
            'remaining_frequencies': remaining_char_frequencies,
            'total_remaining_characters': total_remaining_chars,
            'characters_used_in_top_words': dict(characters_used),
            'original_total_characters': dataset_result['stats']['total_characters'],
            'characters_subtracted': sum(characters_used.values())
        }
        
        updated_results[dataset_name] = updated_dataset_result
    
    return updated_results

def main_processing():
    """Main processing function - analyzes character and word frequencies in datasets."""
    
    # Configuration
    root_dir = '../../../data/text/raw'
    output_dir = '../../../data/text/processed'
    os.makedirs(output_dir, exist_ok=True)
    
    print("Starting dataset processing...")
    
    # Discover datasets
    if not os.path.exists(root_dir):
        print(f"ERROR: Root directory does not exist: {root_dir}")
        return
    
    datasets = [item for item in os.listdir(root_dir) if os.path.isdir(os.path.join(root_dir, item))]
    print(f"Found {len(datasets)} datasets: {datasets}")
    
    # Process each dataset
    results = {}
    for dataset_name in datasets:
        # Define character sets based on dataset
        if dataset_name.lower() == 'cartigratis':
            allowed_letters = string.ascii_letters + "ăâîșțĂÂÎȘȚ"
        else:
            allowed_letters = string.ascii_letters
        
        allowed_digits = string.digits
        allowed_symbols = string.punctuation + " \t\n"
        
        # Initialize counters
        char_counter = Counter()
        category_counters = {
            'letters': Counter(),
            'digits': Counter(),
            'symbols': Counter()
        }
        word_counter = Counter()
        
        total_chars = 0
        total_words = 0
        
        # Process all files in the dataset
        dataset_path = os.path.join(root_dir, dataset_name)
        
        # Walk through all files in the dataset directory
        for root, dirs, files in os.walk(dataset_path):
            for file in files:
                file_path = os.path.join(root, file)
                try:
                    with open(file_path, 'r', encoding='utf-8', errors='ignore') as f:
                        content = f.read()
                        
                        # Process characters (unchanged)
                        for char in content:
                            total_chars += 1
                            
                            if char in allowed_letters:
                                char_counter[char] += 1
                                category_counters['letters'][char] += 1
                            elif char in allowed_digits:
                                char_counter[char] += 1
                                category_counters['digits'][char] += 1
                            elif char in allowed_symbols:
                                char_counter[char] += 1
                                category_counters['symbols'][char] += 1
                        
                        # Extract valid words using improved method
                        valid_words = extract_words_from_text(content, allowed_letters)
                        
                        # Count words
                        for word in valid_words:
                            word_counter[word] += 1
                            total_words += 1
                
                except Exception as e:
                    print(f"Error processing file {file_path}: {e}")
        
        # Calculate character frequencies (unchanged)
        char_frequencies = {}
        for char, count in char_counter.items():
            relative_freq = count / total_chars if total_chars > 0 else 0
            char_frequencies[char] = {
                'absolute': count,
                'relative': relative_freq
            }
        
        # Calculate category-specific frequencies (unchanged)
        category_frequencies = {}
        for category, counter in category_counters.items():
            category_frequencies[category] = {}
            category_total = sum(counter.values())
            for char, count in counter.items():
                relative_freq = count / category_total if category_total > 0 else 0
                category_frequencies[category][char] = {
                    'absolute': count,
                    'relative': relative_freq,
                    'category_relative': relative_freq
                }
        
        # Convert word counter to sorted list by frequency
        sorted_words = []
        for word, count in word_counter.most_common():
            relative_freq = count / total_words if total_words > 0 else 0
            sorted_words.append({
                'word': word,
                'absolute': count,
                'relative': relative_freq,
                'percentage': relative_freq * 100
            })
        
        # Prepare result for this dataset
        result = {
            'config': {
                'allowed_letters': allowed_letters,
                'allowed_digits': allowed_digits,
                'allowed_symbols': allowed_symbols,
                'min_word_length': 2
            },
            'stats': {
                'total_characters': total_chars,
                'unique_characters': len(char_counter),
                'total_words': total_words,
                'unique_words': len(word_counter)
            },
            'character_frequencies': char_frequencies,
            'category_frequencies': category_frequencies,
            'word_frequencies': sorted_words
        }
        
        results[dataset_name] = result
        print(f"Processed {dataset_name}: {total_chars} chars, {len(word_counter)} unique words")
        
        # Show sample of top words for debugging
        print(f"  Top 10 words: {[w['word'] for w in sorted_words[:10]]}")
    
    # Calculate remaining character pool after typing top N words
    print(f"\nCalculating remaining character pool for top {TOP_N_WORDS} words...")
    results_with_remaining_pool = calculate_remaining_character_pool(results, TOP_N_WORDS)
    
    # Save results
    pickle_file = os.path.join(output_dir, 'frequency_analysis.pkl')
    with open(pickle_file, 'wb') as f:
        pickle.dump(results_with_remaining_pool, f)
    
    json_file = os.path.join(output_dir, 'frequency_analysis.json')
    with open(json_file, 'w', encoding='utf-8') as f:
        json.dump(results_with_remaining_pool, f, ensure_ascii=False, indent=2)
    
    print(f"\nProcessing complete. Results saved to:")
    print(f"  Pickle: {pickle_file}")
    print(f"  JSON: {json_file}")
    
    return results_with_remaining_pool

# Additional utility function for analysis
def analyze_word_patterns(results, dataset_name):
    """Analyze patterns in the word data for debugging"""
    if dataset_name not in results:
        print(f"Dataset {dataset_name} not found")
        return
    
    words = results[dataset_name]['word_frequencies']
    
    print(f"\nAnalysis for {dataset_name}:")
    print(f"Total unique words: {len(words)}")
    
    # Length distribution
    length_dist = Counter()
    for word_data in words:
        length_dist[len(word_data['word'])] += 1
    
    print("Word length distribution:")
    for length in sorted(length_dist.keys()):
        print(f"  Length {length}: {length_dist[length]} words")
    
    # Show words with unusual patterns
    suspicious_words = []
    for word_data in words[:50]:  # Check top 50
        word = word_data['word']
        if any(char.isdigit() for char in word) or len(word) == 1:
            suspicious_words.append(word)
    
    if suspicious_words:
        print(f"Suspicious words found: {suspicious_words}")
    else:
        print("No suspicious words in top 50")

# Function to load and analyze existing pickle file
def load_and_update_pickle(pickle_path=None):
    """Load existing pickle file and update with remaining character pool"""
    if pickle_path is None:
        pickle_path = '../../../data/text/processed/frequency_analysis.pkl'
    
    if not os.path.exists(pickle_path):
        print(f"ERROR: Pickle file does not exist: {pickle_path}")
        return None
    
    # Load existing results
    with open(pickle_path, 'rb') as f:
        results = pickle.load(f)
    
    print(f"Loaded existing results with {len(results)} datasets")
    
    # Update with remaining character pool
    print(f"Calculating remaining character pool for top {TOP_N_WORDS} words...")
    updated_results = calculate_remaining_character_pool(results, TOP_N_WORDS)
    
    # Save updated results back to file
    output_dir = os.path.dirname(pickle_path)
    updated_pickle_file = os.path.join(output_dir, f'frequency_analysis_updated_top_{TOP_N_WORDS}.pkl')
    updated_json_file = os.path.join(output_dir, f'frequency_analysis_updated_top_{TOP_N_WORDS}.json')
    
    with open(updated_pickle_file, 'wb') as f:
        pickle.dump(updated_results, f)
    
    with open(updated_json_file, 'w', encoding='utf-8') as f:
        json.dump(updated_results, f, ensure_ascii=False, indent=2)
    
    print(f"Updated results saved to:")
    print(f"  Pickle: {updated_pickle_file}")
    print(f"  JSON: {updated_json_file}")
    
    return updated_results

# Execute processing
if __name__ == "__main__":
    results = main_processing()
    
    # Analyze Romanian data specifically
    if 'cartigratis' in results:
        analyze_word_patterns(results, 'cartigratis')
    
    # Example of accessing the new remaining character pool data
    for dataset_name, dataset_result in results.items():
        if f'{TOP_N_WORDS}_remaining_characters_pool' in dataset_result:
            remaining_data = dataset_result[f'{TOP_N_WORDS}_remaining_characters_pool']
            print(f"\n{dataset_name} - Remaining character pool after typing top {TOP_N_WORDS} words:")
            print(f"  Total remaining characters: {remaining_data['total_remaining_characters']}")
            print(f"  Characters subtracted: {remaining_data['characters_subtracted']}")
            print(f"  Original total: {remaining_data['original_total_characters']}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 10
#       8 sys.path.append('..')
#       9 sys.path.append('..')
# ---> 10 from config.config import TOP_N_WORDS
#      12 def is_valid_word(word, allowed_letters, min_length=2):
#      13     """Check if a word is valid (contains only letters and meets minimum length)"""
#
# ModuleNotFoundError: No module named 'config'

# %%
import pickle
import pandas as pd

# Load the pickle file
with open('./processed/frequency_analysis.pkl', 'rb') as f:
    results = pickle.load(f)

# Get the maximum number of words across all datasets
max_words = max(len(data['word_frequencies']) for data in results.values()) if results else 0

# Create a combined table with top 1000 words
all_datasets = list(results.keys())
top_n = min(1000, max_words)  # Use minimum of 1000 or max words available

# Create DataFrame with rank and words from each dataset
table_data = {'Rank': range(1, top_n + 1)}

for dataset_name in all_datasets:
    words = results[dataset_name]['word_frequencies']
    dataset_words = []
    for i in range(top_n):
        if i < len(words):
            dataset_words.append(words[i]['word'])
        else:
            dataset_words.append('')  # Empty if no word at this rank
    table_data[dataset_name] = dataset_words

# Create the DataFrame
df = pd.DataFrame(table_data)

# Display the table
print(f"Top {top_n} words comparison across datasets")
print(f"Datasets: {', '.join(all_datasets)}")
print("="*80)

# Print the table
print(df.to_string(index=False, max_rows=1000, max_colwidth=30))
# Out:
# Top 1000 words comparison across datasets
# Datasets: simple_wikipedia, the_algorithms_code, gutenberg, cartigratis, newsgroup
# ================================================================================
#  Rank simple_wikipedia      the_algorithms_code     gutenberg   cartigratis     newsgroup
#     1              the                      the           the            de           the
#     2               of                       if           and            în            to
#     3               in                      int            of            să            of
#     4              and                   return            to            nu           and
#     5               is                       of            in            pe            in
#     6               to                     node          that            se            is
#     7              was                      for            he            cu          that
#     8               it                       to            it            la            ax
#     9               he                       is           was            un            it
#    10               on                       in           his            că           for
#    11              for                     self           you          care           you
#    12               as                      new          with           mai          from
#    13               by                     list            is            și            on
#    14             from                     test           for           din          this
#    15             that                    array            as            ce            be
#    16             with                   public           not           lui           not
#    17              are                    value           had            am           are
#    18               at                     this           but            ca          have
#    19               an                      and            be           dar           edu
#    20              his                    graph            at            te          with
#    21             they                   string            my           era            as
#    22               or                   number           her        pentru            or
#    23             also                      key            on            el            if
#    24             this                   import          this            fi           was
#    25             were                   assert          have            ei           but
#    26              has                     tree         which            ar          they
#    27              she                    index            by            ea       subject
#    28               be                     left           him            mi           can
#    29           people                      var            me            au     newsgroup
#    30            first                     size           all            mă            id
#    31            which                    param           she            ii      document
#    32              not                   length          from          este            by
#    33              one                    right            so            îi            re
#    34             born                     void          they           cum           com
#    35             have                     null            or          când            at
#    36            there                      end            no            le            an
#    37            their                     root           are          dacă          what
#    38              had                     data           one            va         there
#    39            after                    const          said            ne            my
#    40              new                     true          what            ai           all
#    41              her                 function            we            al            we
#    42              but                     from         there          după         would
#    43           united                   result          were          nici           one
#    44            other                       it            if            ie            do
#    45              who                       be           who           iar          will
#    46             city                      def            an           sau            he
#    47            known                      let          will            ia         about
#    48              can                    class            de            îl        writes
#    49             many                    false          when          fost            so
#    50              its                      add         their          asta            no
#    51             when                   expect         would          într          your
#    52         american                  integer          them            eu           has
#    53           states                      std          your          acum           any
#    54            about                     next            do            ti       article
#    55              two                     else          been           tot            me
#    56           called                      not          then          sunt          some
#    57             used                     with          more          prin           who
#    58             made                      arr           man          bine         which
#    59             most                      get           out           lor           out
#    60              may                    count           now         poate           don
#    61             some                      set           que          avea          more
#    62            world                      org            up          mult          like
#    63             time                    input          some         toate        people
#    64              all                  returns           any            in          just
#    65           county                  current         could          fără          when
#    66             been                      max          very         chiar          were
#    67             more                   static          into          mine         their
#    68             died                   should          than            da            up
#    69            movie                   parent         other          spre          know
#    70             into                     that          time           îmi           how
#    71           during                  private           did         putea         other
#    72           became                  element          such           ele           get
#    73         national                       or          good           fie          only
#    74            state                    stack          like        atunci          them
#    75             part                   vertex           our          apoi          than
#    76            years                  summary          well            fa           had
#    77          because                       an           has        despre         think
#    78               th                      len          only          ceva           his
#    79             only                     sort           can           mea          been
#    80           played                    queue           how          cînd          also
#    81             name                     edge            la           voi          does
#    82            these                   matrix        should          erau          time
#    83               up                       as          upon          unde          then
#    84             like                   insert           may           are           use
#    85            north                    while         about           noi         these
#    86             than                   search           see           cel          good
#    87          january                    https          know          timp           new
#    88          between                      sum          must       trebuie         could
#    89            south                      num         these            ul        should
#    90           france                     heap         shall          face          well
#    91             team                    first          come            sa            am
#    92             them                      com        before          mare           may
#    93             over                   double            am         decât       because
#    94           number                 expected        little          atât          comp
#    95             year                    using          made            vă           god
#    96            where                     item          much          aici          even
#    97             then                      str           two           meu           now
#    98            later                    range         great           vor            us
#    99            would                     name           its         acolo       windows
#   100             such                     find            us           ale           see
#   101             very                    start         first         nimic           why
#   102            three             assertequals           say         aceea          very
#   103               de                     func         where           via          into
#   104              won                      all          here          până           way
#   105         released                     head         after         numai           two
#   106            until                      min            go            pu          many
#   107           series                     java         never        domnul           apr
#   108       university                    empty       himself          prea          much
#   109            march                      are           sir        foarte          make
#   110              him                       by           own          doar         first
#   111              war                      map          most           cei           max
#   112            found                algorithm            mr          însă           say
#   113            music                     tobe         those            tu         those
#   114              out                 elements          over         făcut            ve
#   115              age                     time          down            it          such
#   116           second                     none          thou        dintre          most
#   117               so                   values           old          spus            ca
#   118        september                   vector         being          căci         right
#   119            album                     case           day            to          here
#   120             july                    final       without          cele        system
#   121        different                     math           men           sim          talk
#   122           august                    print          life           fel           sci
#   123             area                   sorted           too         spuse         where
#   124          october                       we         again         spune           did
#   125             june                  include          make         ochii           our
#   126            since                       at            en          încă        anyone
#   127             song                      val          even         peste           rec
#   128        president                     push          same           zis          want
#   129           before                       on           don         acest            cs
#   130         november                   remove           way          unui            go
#   131            april                    given           let           ani         being
#   132         december                      two           yet      dumnezeu          said
#   133         district                    check         might           mul         after
#   134             best                   binary          long           cea          used
#   135             town                    point        though          două           its
#   136             will                     last         think           cât          same
#   137            group                    float          came           sub          over
#   138       department                     main       thought       înainte          misc
#   139         february                    equal         every           pot          need
#   140           region                     util         still       fiecare          work
#   141               no                      one       nothing          ceea           too
#   142           member                  numbers          away       această     something
#   143               if                     nums          many           nou        please
#   144             same                 solution          hand         toată        really
#   145             make                     char          king          unei       problem
#   146         football                    nodes          work          unul       believe
#   147            often                   append          eyes           dat           him
#   148            being                    child          take         parte         since
#   149             game                      vec          went          tine         space
#   150          started                   system     gutenberg           ora          back
#   151             well                  package          love          sînt         still
#   152            party                     hash        people         totul           off
#   153           family                   random       another     niciodată          mail
#   154              use                     each          just            zi          file
#   155            named               algorithms         house            ci         going
#   156             said                     word           why           său      religion
#   157          british                      out       through            re          find
#   158             both                     bool           thy       aproape         point
#   159       government                    edges       project            ni          help
#   160          through                      row          give         între        before
#   161           school                     path          last         lumea          take
#   162            river                     temp            se          urmă            ll
#   163       television                      nil          once          trei          year
#   164             work                      can            le           ori         using
#   165             each                 vertices          back           loc      question
#   166             west                  boolean            el        acesta   information
#   167             long                      use         while        oameni         might
#   168          commune                       fn        father          ilor          read
#   169              did                    throw       because         acela         years
#   170          english                    junit          tell          cine         never
#   171            while                  addedge         right         lucru          last
#   172          however                    order         under            om        thanks
#   173           player                wikipedia           off        astfel        things
#   174               do                   weight         place            ta          must
#   175          against                   output        things         multe        better
#   176           around                     uint          ever           fac         while
#   177            place                    table            ll         vreme    government
#   178             east               complexity         young          zise          both
#   179             four                     type          head           așa      politics
#   180            under                      has           god          spun           bit
#   181       population                 distance           saw         orice           own
#   182           league                    which          look           una      hardware
#   183             show              assertequal           yes          facă           etc
#   184              day                    error         found          cred         world
#   185          usually                   target         night       aceasta        number
#   186        including                   height          face        aceste       another
#   187            women                 position         world       oamenii          sure
#   188             york                 contains           new           ile      graphics
#   189           season                     text          room          dată       without
#   190            water                    brief          whom      asemenea         david
#   191             main                arraylist           put      domnului       someone
#   192            lived                   source         heart        asupra          made
#   193     municipality                     than        always         lângă         doesn
#   194             band                       en          thee           cap         state
#   195          century                     cout        having        timpul       program
#   196            based                      mid           nor        fusese          data
#   197          several                     keys          part         locul     christian
#   198             king                     then          also           tiu            pc
#   199          country                      pop          took           jos       through
#   200            small                   author         three         văzut           let
#   201            could                    where          mind         decît          down
#   202             john                     base          both      scarlett       between
#   203           former                      mut       against        nimeni           got
#   204              old                  problem        myself         seama          long
#   205             high                      res          thus         parcă         thing
#   206         province                   points     something          mele           mac
#   207            house                     long          left           tău         drive
#   208             life                   method           get        câteva          part
#   209             live                 children         whole         capul    university
#   210              now                     wiki         thing        nevoie          look
#   211             back                       no         heard           vie         under
#   212           french                    prime          lord           doi     available
#   213            began                       do          each          mama           few
#   214            death                  testing        seemed           rău           day
#   215         children               asserttrue          done           tia          come
#   216             home                namespace        looked          pînă      software
#   217           person                     when       chapter           ine          fact
#   218            games                    other        better       început        little
#   219          created                  require            et           sus          case
#   220           system                   delete         going            ru      anything
#   221             went                     will           far          ziua        around
#   222    international                      any          told           bun           sys
#   223            large                     must          name            or         power
#   224             club                     file       between       departe       however
#   225          germany                      log           mrs         părea            ms
#   226              end                    found         asked           își          each
#   227          company                    tests          door          pare           ibm
#   228        important                     trie        cannot          totu            uk
#   229            early                  visited           got         afară          didn
#   230          another               collection        mother          sale           law
#   231       politician                  example           son           iei       against
#   232         language                  isempty         words        cineva         again
#   233              way                   printf        moment            ma          news
#   234              any                    items         began        trebui         every
#   235           single               valueerror          poor       fiindcă          give
#   236          general                  jupiter          lady          zice          true
#   237          england                 sequence         hands           bra         seems
#   238              get                       dp           set          iile          best
#   239             what                     have         quite          fiul          john
#   240          include                 tostring          seen          zile     different
#   241          million                 override          dear          avut      probably
#   242             book                   linked         power           tii           key
#   243           german               linkedlist          find         tatăl         sport
#   244            times                   object            oh          luat           she
#   245             left                  toequal         state         dintr           dos
#   246           census                     tail          full         venit          game
#   247             last                     only          felt          omul         least
#   248            japan                   psjava         woman          tare           set
#   249          example                  pattern          soon          atît          name
#   250            award                       eq        called            ve          tell
#   251        countries                      put         death       noastră      computer
#   252          capital                    cache        nature          vrea           try
#   253             much                    color          true        numele           car
#   254           island                 capacity     therefore        nostru        enough
#   255        sometimes                      bit         years          cari           put
#   256         minister                   create         speak         vreau            ac
#   257          written                     used          word         către        course
#   258               st           implementation          does         putut           run
#   259              you                 testcase          knew            ra      actually
#   260          popular                     same         whose          casa          real
#   261            great                       np       however         vedea          line
#   262            means            thealgorithms        indeed           văd           lot
#   263             play                   struct        friend         încât          list
#   264           famous                     prev        almost          bună         great
#   265             near                     code          till          mâna          post
#   266          species                   second         since        există         image
#   267       california              currentnode           use            na          life
#   268            still               assertions           end          iată          says
#   269          kingdom                      bst       perhaps           vei         jesus
#   270            white                      api           los       lucruri           far
#   271          married                     into            un     împotriva        either
#   272          largest                    local          home            po           her
#   273             even                     most          gave        singur          high
#   274              how                   arrays         round        israel           org
#   275            built                      you          side        partea        though
#   276            wrote                   github          want         celor       support
#   277            third                      pos          hear         drept         group
#   278             five                    query          hath         inima          hard
#   279             took                character         light         acasă            os
#   280              man                calculate          half         măcar          free
#   281             list                 previous      anything            du           old
#   282            black                  minimum           few            at           man
#   283          central                     call         cried          urma        called
#   284            moved                    entry        course      adevărat      possible
#   285           father                  maximum       country        doamna       nothing
#   286           london                    space        prince          eram        hockey
#   287              cup                      top        rather      împreună        second
#   288        australia                  default       present          oare           end
#   289            actor                  println          kind           dea        rather
#   290            india                 describe       believe      probabil         wrong
#   291           common                 negative            re           tie            cc
#   292             land                    break          best          mari          mean
#   293         directed                     some         voice       trebuia          else
#   294              sea                  message       looking           dau            mr
#   295            major                    merge           con       noastre           sun
#   296          history                  license        enough         prima           net
#   297          members                arguments        others       printre         files
#   298             came                      see       certain        ridică        reason
#   299               ii                      mod       whether          isus           gov
#   300           become                      idx         among           cît          call
#   301             good                 treenode        turned          uită           yes
#   302           worked                    after           law        repede          card
#   303             held                   update        person      picioare       version
#   304             army                      err          days       domnule          mark
#   305           living                   digits       herself          vrei        public
#   306             form                    there        matter         ajuns        person
#   307              own                exception          miss         jurul         above
#   308        following                     step        letter           pus         based
#   309              top                     zero            lo          ăsta       looking
#   310               la                      non         taken            ri            de
#   311           summer                      its    themselves        struan         found
#   312          western                  reverse          wife         auzit          next
#   313            given                  doctest         leave         clipă           non
#   314           singer                  between       morning     lucrurile          keep
#   315             line                    raise       brought         mereu        others
#   316              men                     make         money         aveau      problems
#   317             rock                     pair         alone          greu         email
#   318            power                fibonacci         given          vreo           yet
#   319         together                      adj        within          lini          team
#   320           church                       so       already        tocmai          done
#   321              air                      pub        master          alte          seen
#   322              law                     line          case        destul      baseball
#   323             down                  hashmap            qu        trecut          able
#   324            again                     init         order            nd       example
#   325          america                     curr          soul      înaintea          guns
#   326               go                    match      together            ac         maybe
#   327             park                  strings       general            dă          send
#   328           things                    total    everything            en        having
#   329              son                      low          less       întrebă          bill
#   330            union                    depth       replied          învă         order
#   331           public                    state        reason          ochi           isn
#   332             body                   prefix           por          casă        always
#   333           career                  sorting         works         patru       general
#   334              set                reference        either         sigur          book
#   335           served                     swap       towards          abia           bad
#   336             role                  process         often          faci         wrote
#   337             film                recursive          keep        femeie          ever
#   338            total                     copy            il        înapoi         place
#   339         election                    usize       brother          lume       thought
#   340             just                      col         means            an          info
#   341             word                    power          gone       acestea         quite
#   342          founded                 iterator          next          câte         three
#   343           center                    pivot          says       răspuns          nasa
#   344              red                      run        states          avem           gun
#   345            using                     iter          hope           mod     following
#   346            video                      dfs          dead         domni         doing
#   347         northern                    words         stood           dus            st
#   348             aged                   equals         child        pământ          once
#   349            order                     loop       friends          altă          less
#   350            stars                  greater          read           con         heard
#   351             does                   recent         enter          deja      evidence
#   352          station              description    understand      deasupra      internet
#   353             frog                   square          sure        drumul          chip
#   354            young               structures         point        moment        trying
#   355          college                traceback           air           reu            mb
#   356              off                       ds          call          hans        window
#   357            parts                     endl          help         făcea         phone
#   358           movies                     high        second           vom       whether
#   359            along           datastructures        itself            ro         given
#   360             next                      red        really       imediat       control
#   361               us                     bits         white          vine        israel
#   362         european                   common         small       spatele       several
#   363              got                     byte           las           tai         means
#   364             term                     less            ye         felul           ftp
#   365         japanese                      www           les      privirea          left
#   366     professional                  decimal          rest           mor         times
#   367     championship                 unittest      answered           lua           won
#   368        published                    board          near          fapt      research
#   369             head                       up          fear           apă       systems
#   370             seat                  compare            su           dac       atheism
#   371            saint                      try         water            er          idea
#   372            every                  newnode           bed          afla         human
#   373              big                 positive         least           fiu           big
#   374           canada illegalargumentexception          fact          ului        access
#   375            plays                     area        manner         cinci         start
#   376          village                     free          wish           cam            hp
#   377        political                    digit          mean       diminea          away
#   378            human                  foreach         truth          veni      children
#   379           making                    level          live         peter          word
#   380               km                     dist         count          acea       getting
#   381             help                  hundred          body        trupul          kind
#   382             type                    valid           lay          făcu       michael
#   383            short                     grid         times           mei         today
#   384         republic                      but          high        lumina          home
#   385           modern                      abs            si   întotdeauna          code
#   386           killed              collections          sent        faptul          note
#   387              few               characters          used        târziu          seem
#   388              six                     more            th          simt           win
#   389            those                     back          mine           rog        during
#   390            works                 integers      suddenly          sfâr     questions
#   391          located                   column            ve          vadă      remember
#   392            italy                  invalid          open        noapte        source
#   393             take                  convert          book          cuno         makes
#   394           indian                 neighbor     gentleman           fii      american
#   395         southern                      gcd           art            im        netcom
#   396          thought                     rows      children          tiin        change
#   397            story                     cost      question         spună           alt
#   398             side                    black        passed         fiind      standard
#   399          actress                   export            st          mână        cannot
#   400            right                      mat          fire         putem          paul
#   401         director                   before          four          ales         apple
#   402           europe                addvertex        return          oară            au
#   403             days                   throws         earth            ba           fax
#   404            songs                otherwise        heaven          voia         steve
#   405         received                     link        common          iuda      opinions
#   406          italian                 problems         cause       noaptea         stuff
#   407           studio                       io        become          drum          full
#   408              due                  version        behind dumneavoastră          scsi
#   409           mother                   stream          turn           ara          uucp
#   410             seen                      ans        answer          vezi       already
#   411         produced                    deque          arms           mii         bible
#   412         military                   single           sat            so     president
#   413               we                 listnode          else          tale         large
#   414            today                    based          hour         rămas       perhaps
#   415        according                     peek         queen           mie         games
#   416              led                  exports         table           cer          mike
#   417            james                  product           boy           ace         until
#   418            money                     tkey         black        începu         local
#   419            light                    block       subject        suntem           ask
#   420            china                  extends         above        doamne        saying
#   421          without                       de           sea         astea          uiuc
#   422         building                  initial     sometimes        adevăr          jews
#   423             lost                   filter          girl          gura         price
#   424            court                  longest          sort         copil          disk
#   425             food                traversal        spirit           gre       address
#   426          special                   middle          lost    picioarele       message
#   427          formula                  pointer        fellow           mic         small
#   428             late                     move          free        copiii        answer
#   429           leader                       id      received          mîna         color
#   430            level                structure           ask          duce       running
#   431          similar                factorial         terms         stare         money
#   432              see                     sqrt          form          eles          show
#   433           others                       go         known          masă           war
#   434           office                   actual          five          auzi      national
#   435             away                    union          fell           for            co
#   436           period              destination          laws           alt           med
#   437           joined                    split          unto      jumătate          play
#   438              art                 unsorted     different      răspunse       current
#   439         governor                    image            ah         odată          days
#   440          elected                 priority         large          pune         speed
#   441            prime                 variable        coming        altfel          came
#   442        character                  enqueue         forth         vorba   electronics
#   443         although                      src          care        bărbat    interested
#   444          version                     side         blood       cuvinte       science
#   445            earth                     inst       several            câ           ago
#   446           awards                   primes        during       privire         issue
#   447          eastern                  builder       husband       singură          type
#   448           formed                  results          feel        simplu      original
#   449            lives                   passed        family         multă        pretty
#   450          playing                      was         along          vrut          told
#   451             star                 generate           war       castorp         agree
#   452              lot                  minheap           qui            li         whole
#   453              san                   module         happy       mâinile           buy
#   454             lake              assertfalse      business         minte         works
#   455          william                specified         human          doua          hope
#   456           george                    times       evening        aminte        matter
#   457         original                    store            es      sufletul       machine
#   458        announced               dictionary        french         altul          open
#   459            roman                    three        making          nouă            th
#   460           battle               operations      thousand           pre         often
#   461           caused                  counter        honour         exact          feel
#   462              put                  without        longer           cre        andrew
#   463            books                   exists        saying        stătea    understand
#   464         olympics                     both         scene        spunea        center
#   465           little                    hello         short          spui          love
#   466          service                   params    foundation           duc          sale
#   467             love                  complex          able         deloc        rights
#   468            title                  dynamic            ne           ină           jim
#   469          changed                 starting          hold           aer           box
#   470            makes                     does      possible            iu       display
#   471            local                    cycle       feeling           obi    everything
#   472           mostly                     dict          town       tuturor        robert
#   473           record                  hashset         women           tea          mind
#   474            final                       ok         horse        vremea         claim
#   475       australian                    width           del     cuvintele        simply
#   476            royal                substring          fair          unii          hand
#   477          russian              constructor          duke          mătu        memory
#   478             free                   linear       hundred      întrebat          care
#   479           soviet                   letter           eye          vede        states
#   480              god                  weights      remember           pat        church
#   481           empire                  whether          show         niște          live
#   482            texas                    bytes       species        plecat      everyone
#   483            point               comparator          idea         spate           men
#   484         appeared                    front        public      întoarce     important
#   485           change               biginteger        united          unor         earth
#   486           groups                      cur    government        uneori           soc
#   487             gave                   format       strange           vin       history
#   488           social                  segment           ten        război       forsale
#   489           attack                 original      daughter          alta          went
#   490            drama                 continue       natural        întors         april
#   491            event                  largest         ready          acel      programs
#   492          spanish                      may         doubt     împăratul        almost
#   493           places                 possible        ground      înseamnă       clipper
#   494          control                   factor      yourself          aibă         autos
#   495            match                      obj    electronic         încet   motorcycles
#   496            areas                insertion         ought          inea        server
#   497         included                       pi         bring          plin          side
#   498           middle                  testmod       opinion         david            ed
#   499        community                      sub       neither         aveam         cause
#   500            shows                      tmp      pleasure        primul         video
#   501             less                 directed        sister         copii     certainly
#   502               tv                   buffer      returned         privi      armenian
#   503      switzerland                  inorder         sense         clipa     including
#   504              run                    label        france        ceilal         crypt
#   505          academy                  sibling          elle            aș           mit
#   506         canadian                  avltree          kept          fiin    christians
#   507           rights               palindrome       society          bani         guess
#   508             wife                    begin         sight          sine       include
#   509         division                    enter          talk        mintea         comes
#   510           wanted                    limit       account          dădu            vs
#   511            heart                 software         until         seara        wouldn
#   512            among                 internal          land          gata        wanted
#   513          council                    shift          year         cauza    encryption
#   514               al                hashtable          feet            ți         later
#   515          animals                 areequal          held         părin    technology
#   516           police                  subtree     certainly         avram         death
#   517         includes                    tuple           bad           azi         faith
#   518            spain                     want         seems          zece            ok
#   519           africa               comparable        number         adică       instead
#   520            force               initialize           met        precum        christ
#   521           though                   cipher          none      întoarse          area
#   522             race                functions           won            fu        making
#   523          science                      got          bear        curând         check
#   524          chinese                   python           est          mică       working
#   525            comes                    lists        became       deodată         white
#   526          instead                    place           act          dela          copy
#   527           robert                      pow           ill          știu            pl
#   528           female                  removed        change           uri        jewish
#   529               re                     args            ii       trebuit           low
#   530           within                 adjacent       suppose           spa            hi
# ...
#   824           bridge                      exp       pleased        oricum         along
#   825          smaller                       ll     important          rând       rutgers
#   826             size                     unit       minutes       femeile         legal
#   827             data                     game        wonder          beth        belief
#   828         believed          implementations         field      singurul            cx
#   829            mayor                     full          died         moise         wants
#   830            fight                 provided         below        credin        player
#   831           design                      utf        notice         arată           san
#   832           theory                   malloc         worse         urile         leave
#   833          stadium                      old       instant          cîte          lord
#   834          schools                extension           hab           ore      military
#   835           longer        argumentexception          news      îndoială        bitnet
#   836         congress                   suffix       quickly         vechi       related
#   837            wales                variables            jo        strada           act
#   838           humans                   action          walk            nc         chris
#   839             arts                    stdio         march         brock         total
#   840     organization                  replace         grace           joc        policy
#   841             tour                     they          hast        poartă          tape
#   842        northwest                      big        placed          nino          term
#   843            opera               difference        wished       fratele           sin
#   844         austrian                    worst          deal        vostru        league
#   845         chemical                    chain        merely    pământului       million
#   846         carolina                encrypted        easily         umesc  applications
#   847             told                     form      greatest          apar      virginia
#   848           cannot                    visit         steps      frumoasă     reference
#   849         soldiers                    means         meant         aerul       deleted
#   850             hill                   colors         enemy       ascultă           cut
#   851         assembly                prototype    individual          adar           pat
#   852           border                     once        remain        rămâne        muslim
#   853    championships                    model     influence          duse   appreciated
#   854          britain                      way        porque          voie      involved
#   855          process                  natural         front       melanie         ideas
#   856          systems               represents         usual           las            fi
#   857           oldest                 greatest      straight       voastre           gas
#   858         designed                      php         heavy      cunoscut         cases
#   859              van                      ord         piece          trup       section
#   860        wrestling                   subset        danger           nop      previous
#   861          nations                   symbol        middle        intrat         speak
#   862         pictures                    bound          blue     capitolul     necessary
#   863         scotland                    large           par       iubirea            cb
#   864               bc                      img         drink        crezut       explain
#   865          awarded                   within         fight        scoase        design
#   866         happened                  toarray          wine      întreaga         motif
#   867         commonly                  removes         moved         calea         worth
#   868     presidential                      fmt        marius          anna            rd
#   869      traditional                       da         trees        ridica        higher
#   870            tried                   player          tone       posibil           ram
#   871           author                     pass         music          sută         reply
#   872             keep                  another          born       anumite          soon
#   873           albums                  defined           una     întuneric        nature
#   874        described               components     trademark         cerul         media
#   875         features               ciphertext circumstances        puteam      comments
#   876               jr                  methods        broken          idee     directory
#   877            korea                intervals      carriage       plăcere      colorado
#   878       discovered                  perform     generally          elor     knowledge
#   879        beginning                  display       promise          area          blue
#   880            upper                     just         study        întorc    population
#   881         champion               binarytree       liberty          page          east
#   882             dark                    sieve        degree      povestea        couldn
#   883          matches                      tag         saint            pm     mentioned
#   884             post                  vectors      language            em          half
#   885            board                       la        proper          scos          site
#   886         missouri                   bubble        beside            bt         knows
#   887              pop                   divide         grave           qxp       himself
#   888          manager              performance           eat      răspunde       outside
#   889       throughout                    would         false         carte           jon
#   890            dance                enumerate        pocket         evolu       present
#   891              bay                   adding     exclaimed         trecu      stanford
#   892   arrondissement                 divisors         glass        plăcea     microsoft
#   893              don                mergesort         forms          lemn         crime
#   894            cross                    these       receive          uria         child
#   895              saw                    angle      creature           gol     currently
#   896        buildings                 datetime      consider          pace         parts
#   897         magazine                 trienode         marry          tată       clearly
#   898           points                 exponent          jean         renun      building
#   899           edward                     many         carry          stai          none
#   900      distributed                  indexof         aside         iilor        report
#   901          stories                     keep       spirits         motiv          land
#   902              ran                    radix            iv     fereastră        theory
#   903            forms                    green          vain         pleca       willing
#   904        religious                     five         learn            tr          sent
#   905              boy                    train         madam         punct           die
#   906             rule                 location        andrew           the       results
#   907           martin                  shuffle           sha        primit       richard
#   908           higher                  ordered    difficulty       singura     algorithm
#   909             vice                       xd        school         puțin        asking
#   910          seasons                     loss       learned          poli         field
#   911          windows                       xa          aunt           tit          main
#   912           larger                     like         dress      pământul           ide
#   913           sister                     read          plus         liber        issues
#   914             mass             representing      distance           ave       purpose
#   915          winning                  cluster         comme        privea       defense
#   916       themselves                   encode         seven      degetele       command
#   917          someone                  arrange         lives      soarelui       weapons
#   918          believe                component      religion       familie      included
#   919           golden             currentindex         whale        gândul         takes
#   920             hand                     mass      entirely        rămase          eric
#   921            cases                successor         fresh      încercat      interest
#   922          georgia               expression    considered         întâi           joe
#   923            goals                     skip           nat       perfect          ways
#   924              iii                   apache         books       muntele         court
#   925           disney                      sin      instance        durere           dan
#   926             iowa               iterations         laugh       suflete     existence
#   927             your               beforeeach         judge         formă          page
#   928        available                interface      expected        întins            dx
#   929          brought                 constant            sa       asculta         cover
#   930           amount                  vertexb         moral      dragoste           sex
#   931             bill                   failed     political        cameră        choice
#   932         starring                     pred           big       ultimul       serious
#   933              eat                    delta         looks        scoate       muslims
#   934            smith                      url       science     încredere    controller
#   935            asian                      dsu          wood        deveni     otherwise
#   936             girl                    strip           hat          eleg       average
#   937             grew                    guard          step          lase            wm
#   938             ways                       tw            te        spunem      complete
#   939              job                    takes     perfectly       atticus        follow
#   940          leading                    pedro       obliged           ina      language
#   941             gets                 argument           tan         carla        george
#   942             laws                   unless            ay       gândesc        exists
#   943           joseph                   center         spite        astrid        claims
#   944          foreign                     slow        breath       amândoi     insurance
#   945    entertainment                      cfg       archive         încît        engine
#   946           length                       xf        tongue           inu        create
#   947        committee                   inputs         stone           ăla          arab
#   948         starting                      bag         ebook          itul    completely
#   949      competition                     adds           fit         oprit       federal
#   950            trade                    zeros       passion          stea         modem
#   951              sex                remainder         begin        doilea            nd
#   952        institute                      xor          grew          anul     objective
#   953          private                       xb       private        altele          base
#   954           animal                  creates          hall      oarecare        sounds
#   955          surface                nodecount         fixed       propria        indeed
#   956         campaign                     auto        places      impresia        chance
#   957            month                   counts           dog   împăratului         cards
#   958          section                 callback        trying           nea        living
#   959        americans                    works          fast           rul         rules
#   960            birds                       xe       command         lungă     anonymous
#   961         followed                    ratio        forget       întreba       created
#   962         animated                      cmp         river            lu       freedom
#   963            track                      day          wise        stradă          batf
#   964          olympic                recursion      property         senza       project
#   965           create                   istrue        sudden          glas        father
#   966             rest              hexadecimal       alyosha         capăt         below
#   967             call                  vicente           due      întâmplă         uunet
#   968       basketball                   unwrap       waiting        meargă       reasons
#   969              fox                    track        social         sânge          drug
#   970         industry                     flag          stop         vedem international
#   971            below                   option          fate           par       library
#   972       eventually                determine        months          tere         basis
#   973         atlantic                      mez       writing           duh      machines
#   974             feet                    being     elizabeth      cuvîntul      division
#   975       tournament                increment          dare        cartea           mil
#   976             code            xctasserttrue        arthur       întinse        normal
#   977             nine                 timeline       passing      dumitale     technical
#   978            covid                  adjlist         shame           com       armenia
#   979          biggest                    nchez          fool       joachim        device
#   980            stone                     rate        cousin         băiat         weeks
#   981           active               references         south            cî        serial
#   982           degree                 reversed       meaning           ura         gives
#   983           israel                 iterable          pain      spiritul          pitt
#   984  representatives                    maths        period      înăuntru         paper
#   985            older                    small       emperor         ciuda         basic
#   986          artists                    force     existence        cunosc        inside
#   987          pacific                     plus        wealth         legea    individual
#   988             kill                  hendrix        filled           urm          king
#   989           jersey                      mst       officer       dreapta      supposed
#   990              met                 counting         wrote            ob           acs
#   991             true                     rear        anyone        treacă          gave
#   992            rules              grandparent       various      potrivit        useful
#   993        companies                  extract        figure    dumnezeule       appears
#   994          studies                     task         sorry          daca     interface
#   995          running                    erdos       drawing       devreme         learn
#   996            fifth                   typeof         cases        făceau        author
#   997            chart              permutation       perfect         pline          arms
#   998             past                    third          mark        pielea         islam
#   999           itself                   always         hence        găsesc      directly
#  1000           doctor               coordinate         devil        mergem           tim

# %%
import pickle
import pandas as pd
from IPython.display import display, HTML

# Load the pickle file
with open('./processed/frequency_analysis.pkl', 'rb') as f:
    results = pickle.load(f)

# Function to create frequency tables for a dataset
def create_frequency_tables(dataset_name, results):
    if dataset_name not in results:
        print(f"Dataset '{dataset_name}' not found!")
        return
    
    data = results[dataset_name]
    char_frequencies = data['character_frequencies']
    category_frequencies = data['category_frequencies']
    
    # Table 1: All characters global percentage
    all_chars_data = []
    for char, freq_data in char_frequencies.items():
        all_chars_data.append({
            'Character': repr(char),  # Use repr to show escape sequences
            'Percentage': f"{freq_data['relative'] * 100:.4f}%"
        })
    
    # Sort by frequency (descending)
    all_chars_data.sort(key=lambda x: float(x['Percentage'].rstrip('%')), reverse=True)
    table1 = pd.DataFrame(all_chars_data)
    
    # Table 2: Letters only
    letters_data = []
    if 'letters' in category_frequencies:
        for char, freq_data in category_frequencies['letters'].items():
            letters_data.append({
                'Character': char,
                'Percentage': f"{freq_data['category_relative'] * 100:.4f}%"
            })
        letters_data.sort(key=lambda x: float(x['Percentage'].rstrip('%')), reverse=True)
    table2 = pd.DataFrame(letters_data)
    
    # Table 3: Symbols only  
    symbols_data = []
    if 'symbols' in category_frequencies:
        for char, freq_data in category_frequencies['symbols'].items():
            symbols_data.append({
                'Character': repr(char),  # Use repr for better visibility of symbols
                'Percentage': f"{freq_data['category_relative'] * 100:.4f}%"
            })
        symbols_data.sort(key=lambda x: float(x['Percentage'].rstrip('%')), reverse=True)
    table3 = pd.DataFrame(symbols_data)
    
    # Table 4: Numbers only
    numbers_data = []
    if 'digits' in category_frequencies:
        for char, freq_data in category_frequencies['digits'].items():
            numbers_data.append({
                'Character': char,
                'Percentage': f"{freq_data['category_relative'] * 100:.4f}%"
            })
        numbers_data.sort(key=lambda x: float(x['Percentage'].rstrip('%')), reverse=True)
    table4 = pd.DataFrame(numbers_data)
    
    return table1, table2, table3, table4

# Function to display tables side by side
def display_tables_side_by_side(dataset_name, results):
    tables = create_frequency_tables(dataset_name, results)
    if tables is None:
        return
    
    table1, table2, table3, table4 = tables
    
    # Convert DataFrames to HTML
    table1_html = table1.to_html(index=False, classes='table-sm', table_id='table1')
    table2_html = table2.to_html(index=False, classes='table-sm', table_id='table2') 
    table3_html = table3.to_html(index=False, classes='table-sm', table_id='table3')
    table4_html = table4.to_html(index=False, classes='table-sm', table_id='table4')
    
    # Create side-by-side layout
    combined_html = f"""
    <style>
        .tables-container {{
            display: flex;
            gap: 20px;
            flex-wrap: wrap;
        }}
        .table-wrapper {{
            flex: 1;
            min-width: 200px;
            max-height: 600px;
            overflow-y: auto;
        }}
        .table-wrapper h4 {{
            text-align: center;
            margin-bottom: 10px;
            color: #333;
        }}
        .table-sm {{
            font-size: 12px;
            width: 100%;
        }}
        .table-sm th, .table-sm td {{
            padding: 4px 8px;
            text-align: left;
        }}
        .table-sm th {{
            background-color: #f8f9fa;
            font-weight: bold;
        }}
        .table-sm tr:nth-child(even) {{
            background-color: #f8f9fa;
        }}
    </style>
    
    <h2>Character Frequency Analysis for: {dataset_name}</h2>
    <div class="tables-container">
        <div class="table-wrapper">
            <h4>All Characters (Global %)</h4>
            {table1_html}
        </div>
        <div class="table-wrapper">
            <h4>Letters Only (%)</h4>
            {table2_html}
        </div>
        <div class="table-wrapper">
            <h4>Symbols Only (%)</h4>
            {table3_html}
        </div>
        <div class="table-wrapper">
            <h4>Numbers Only (%)</h4>
            {table4_html}
        </div>
    </div>
    """
    
    display(HTML(combined_html))

# Display tables for each dataset
print("Available datasets:", list(results.keys()))
print("\n" + "="*80 + "\n")

for dataset_name in results.keys():
    display_tables_side_by_side(dataset_name, results)
    print("\n" + "="*80 + "\n")
# Out:
# Available datasets: ['simple_wikipedia', 'the_algorithms_code', 'gutenberg', 'cartigratis', 'newsgroup']
#
# ================================================================================
#     <style>
#         .tables-container {
#             display: flex;
#             gap: 20px;
#             flex-wrap: wrap;
#         }
#         .table-wrapper {
#             flex: 1;
#             min-width: 200px;
#             max-height: 600px;
#             overflow-y: auto;
#         }
#         .table-wrapper h4 {
#             text-align: center;
#             margin-bottom: 10px;
#             color: #333;
#         }
#         .table-sm {
#             font-size: 12px;
#             width: 100%;
#         }
#         .table-sm th, .table-sm td {
#             padding: 4px 8px;
#             text-align: left;
#         }
#         .table-sm th {
#             background-color: #f8f9fa;
#             font-weight: bold;
#         }
#         .table-sm tr:nth-child(even) {
#             background-color: #f8f9fa;
#         }
#     </style>
#
#     <h2>Character Frequency Analysis for: simple_wikipedia</h2>
#     <div class="tables-container">
#         <div class="table-wrapper">
#             <h4>All Characters (Global %)</h4>
#             <table border="1" class="dataframe table-sm" id="table1">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Character</th>
#       <th>Percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>' '</td>
#       <td>16.1697%</td>
#     </tr>
#     <tr>
#       <td>'e'</td>
#       <td>9.0362%</td>
#     </tr>
#     <tr>
#       <td>'a'</td>
#       <td>6.7394%</td>
#     </tr>
#     <tr>
#       <td>'t'</td>
#       <td>5.9729%</td>
#     </tr>
#     <tr>
#       <td>'n'</td>
#       <td>5.5977%</td>
#     </tr>
#     <tr>
#       <td>'i'</td>
#       <td>5.5493%</td>
#     </tr>
#     <tr>
#       <td>'o'</td>
#       <td>5.4126%</td>
#     </tr>
#     <tr>
#       <td>'r'</td>
#       <td>4.8917%</td>
#     </tr>
#     <tr>
#       <td>'s'</td>
#       <td>4.8147%</td>
#     </tr>
#     <tr>
#       <td>'h'</td>
#       <td>3.4445%</td>
#     </tr>
#     <tr>
#       <td>'l'</td>
#       <td>3.0596%</td>
#     </tr>
#     <tr>
#       <td>'d'</td>
#       <td>2.7257%</td>
#     </tr>
#     <tr>
#       <td>'c'</td>
#       <td>2.1513%</td>
#     </tr>
#     <tr>
#       <td>'u'</td>
#       <td>1.9225%</td>
#     </tr>
#     <tr>
#       <td>'m'</td>
#       <td>1.8887%</td>
#     </tr>
#     <tr>
#       <td>'f'</td>
#       <td>1.4843%</td>
#     </tr>
#     <tr>
#       <td>'p'</td>
#       <td>1.3518%</td>
#     </tr>
#     <tr>
#       <td>'g'</td>
#       <td>1.3126%</td>
#     </tr>
#     <tr>
#       <td>'y'</td>
#       <td>1.2064%</td>
#     </tr>
#     <tr>
#       <td>'w'</td>
#       <td>1.1816%</td>
#     </tr>
#     <tr>
#       <td>'\n'</td>
#       <td>1.1516%</td>
#     </tr>
#     <tr>
#       <td>'.'</td>
#       <td>1.1411%</td>
#     </tr>
#     <tr>
#       <td>'b'</td>
#       <td>1.0606%</td>
#     </tr>
#     <tr>
#       <td>','</td>
#       <td>0.9205%</td>
#     </tr>
#     <tr>
#       <td>'v'</td>
#       <td>0.7103%</td>
#     </tr>
#     <tr>
#       <td>'k'</td>
#       <td>0.5146%</td>
#     </tr>
#     <tr>
#       <td>'1'</td>
#       <td>0.4907%</td>
#     </tr>
#     <tr>
#       <td>'T'</td>
#       <td>0.4323%</td>
#     </tr>
#     <tr>
#       <td>'S'</td>
#       <td>0.4150%</td>
#     </tr>
#     <tr>
#       <td>'0'</td>
#       <td>0.4091%</td>
#     </tr>
#     <tr>
#       <td>'"'</td>
#       <td>0.3773%</td>
#     </tr>
#     <tr>
#       <td>'A'</td>
#       <td>0.3764%</td>
#     </tr>
#     <tr>
#       <td>'2'</td>
#       <td>0.3597%</td>
#     </tr>
#     <tr>
#       <td>'C'</td>
#       <td>0.3236%</td>
#     </tr>
#     <tr>
#       <td>'I'</td>
#       <td>0.3085%</td>
#     </tr>
#     <tr>
#       <td>'9'</td>
#       <td>0.2903%</td>
#     </tr>
#     <tr>
#       <td>'M'</td>
#       <td>0.2717%</td>
#     </tr>
#     <tr>
#       <td>'H'</td>
#       <td>0.2460%</td>
#     </tr>
#     <tr>
#       <td>'B'</td>
#       <td>0.2343%</td>
#     </tr>
#     <tr>
#       <td>'P'</td>
#       <td>0.2106%</td>
#     </tr>
#     <tr>
#       <td>')'</td>
#       <td>0.1723%</td>
#     </tr>
#     <tr>
#       <td>'('</td>
#       <td>0.1721%</td>
#     </tr>
#     <tr>
#       <td>'-'</td>
#       <td>0.1719%</td>
#     </tr>
#     <tr>
#       <td>'D'</td>
#       <td>0.1615%</td>
#     </tr>
#     <tr>
#       <td>'F'</td>
#       <td>0.1608%</td>
#     </tr>
#     <tr>
#       <td>'R'</td>
#       <td>0.1554%</td>
#     </tr>
#     <tr>
#       <td>'L'</td>
#       <td>0.1543%</td>
#     </tr>
#     <tr>
#       <td>'N'</td>
#       <td>0.1494%</td>
#     </tr>
#     <tr>
#       <td>'G'</td>
#       <td>0.1464%</td>
#     </tr>
#     <tr>
#       <td>'8'</td>
#       <td>0.1383%</td>
#     </tr>
#     <tr>
#       <td>'W'</td>
#       <td>0.1369%</td>
#     </tr>
#     <tr>
#       <td>'J'</td>
#       <td>0.1338%</td>
#     </tr>
#     <tr>
#       <td>'E'</td>
#       <td>0.1320%</td>
#     </tr>
#     <tr>
#       <td>'x'</td>
#       <td>0.1247%</td>
#     </tr>
#     <tr>
#       <td>'3'</td>
#       <td>0.1225%</td>
#     </tr>
#     <tr>
#       <td>'7'</td>
#       <td>0.1187%</td>
#     </tr>
#     <tr>
#       <td>'5'</td>
#       <td>0.1185%</td>
#     </tr>
#     <tr>
#       <td>'6'</td>
#       <td>0.1133%</td>
#     </tr>
#     <tr>
#       <td>'O'</td>
#       <td>0.1127%</td>
#     </tr>
#     <tr>
#       <td>'4'</td>
#       <td>0.1115%</td>
#     </tr>
#     <tr>
#       <td>'z'</td>
#       <td>0.1078%</td>
#     </tr>
#     <tr>
#       <td>"'"</td>
#       <td>0.1059%</td>
#     </tr>
#     <tr>
#       <td>'K'</td>
#       <td>0.0961%</td>
#     </tr>
#     <tr>
#       <td>'U'</td>
#       <td>0.0933%</td>
#     </tr>
#     <tr>
#       <td>'j'</td>
#       <td>0.0743%</td>
#     </tr>
#     <tr>
#       <td>'V'</td>
#       <td>0.0683%</td>
#     </tr>
#     <tr>
#       <td>'|'</td>
#       <td>0.0575%</td>
#     </tr>
#     <tr>
#       <td>'q'</td>
#       <td>0.0492%</td>
#     </tr>
#     <tr>
#       <td>':'</td>
#       <td>0.0404%</td>
#     </tr>
#     <tr>
#       <td>'Y'</td>
#       <td>0.0328%</td>
#     </tr>
#     <tr>
#       <td>';'</td>
#       <td>0.0194%</td>
#     </tr>
#     <tr>
#       <td>'Z'</td>
#       <td>0.0165%</td>
#     </tr>
#     <tr>
#       <td>'/'</td>
#       <td>0.0122%</td>
#     </tr>
#     <tr>
#       <td>'Q'</td>
#       <td>0.0114%</td>
#     </tr>
#     <tr>
#       <td>'%'</td>
#       <td>0.0094%</td>
#     </tr>
#     <tr>
#       <td>'X'</td>
#       <td>0.0085%</td>
#     </tr>
#     <tr>
#       <td>'!'</td>
#       <td>0.0053%</td>
#     </tr>
#     <tr>
#       <td>'&amp;'</td>
#       <td>0.0047%</td>
#     </tr>
#     <tr>
#       <td>'$'</td>
#       <td>0.0040%</td>
#     </tr>
#     <tr>
#       <td>'='</td>
#       <td>0.0033%</td>
#     </tr>
#     <tr>
#       <td>'&lt;'</td>
#       <td>0.0033%</td>
#     </tr>
#     <tr>
#       <td>'&gt;'</td>
#       <td>0.0033%</td>
#     </tr>
#     <tr>
#       <td>'_'</td>
#       <td>0.0029%</td>
#     </tr>
#     <tr>
#       <td>'['</td>
#       <td>0.0021%</td>
#     </tr>
#     <tr>
#       <td>']'</td>
#       <td>0.0021%</td>
#     </tr>
#     <tr>
#       <td>'#'</td>
#       <td>0.0021%</td>
#     </tr>
#     <tr>
#       <td>'+'</td>
#       <td>0.0018%</td>
#     </tr>
#     <tr>
#       <td>'?'</td>
#       <td>0.0015%</td>
#     </tr>
#     <tr>
#       <td>'*'</td>
#       <td>0.0007%</td>
#     </tr>
#     <tr>
#       <td>'~'</td>
#       <td>0.0002%</td>
#     </tr>
#     <tr>
#       <td>'{'</td>
#       <td>0.0002%</td>
#     </tr>
#     <tr>
#       <td>'^'</td>
#       <td>0.0001%</td>
#     </tr>
#     <tr>
#       <td>'`'</td>
#       <td>0.0001%</td>
#     </tr>
#     <tr>
#       <td>'\\'</td>
#       <td>0.0001%</td>
#     </tr>
#     <tr>
#       <td>'}'</td>
#       <td>0.0001%</td>
#     </tr>
#     <tr>
#       <td>'@'</td>
#       <td>0.0001%</td>
#     </tr>
#   </tbody>
# </table>
#         </div>
#         <div class="table-wrapper">
#             <h4>Letters Only (%)</h4>
#             <table border="1" class="dataframe table-sm" id="table2">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Character</th>
#       <th>Percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>e</td>
#       <td>11.7394%</td>
#     </tr>
#     <tr>
#       <td>a</td>
#       <td>8.7555%</td>
#     </tr>
#     <tr>
#       <td>t</td>
#       <td>7.7597%</td>
#     </tr>
#     <tr>
#       <td>n</td>
#       <td>7.2722%</td>
#     </tr>
#     <tr>
#       <td>i</td>
#       <td>7.2093%</td>
#     </tr>
#     <tr>
#       <td>o</td>
#       <td>7.0318%</td>
#     </tr>
#     <tr>
#       <td>r</td>
#       <td>6.3550%</td>
#     </tr>
#     <tr>
#       <td>s</td>
#       <td>6.2550%</td>
#     </tr>
#     <tr>
#       <td>h</td>
#       <td>4.4749%</td>
#     </tr>
#     <tr>
#       <td>l</td>
#       <td>3.9748%</td>
#     </tr>
#     <tr>
#       <td>d</td>
#       <td>3.5411%</td>
# ================================================================================
#     <style>
#         .tables-container {
#             display: flex;
#             gap: 20px;
#             flex-wrap: wrap;
#         }
#         .table-wrapper {
#             flex: 1;
#             min-width: 200px;
#             max-height: 600px;
#             overflow-y: auto;
#         }
#         .table-wrapper h4 {
#             text-align: center;
#             margin-bottom: 10px;
#             color: #333;
#         }
#         .table-sm {
#             font-size: 12px;
#             width: 100%;
#         }
#         .table-sm th, .table-sm td {
#             padding: 4px 8px;
#             text-align: left;
#         }
#         .table-sm th {
#             background-color: #f8f9fa;
#             font-weight: bold;
#         }
#         .table-sm tr:nth-child(even) {
#             background-color: #f8f9fa;
#         }
#     </style>
#
#     <h2>Character Frequency Analysis for: the_algorithms_code</h2>
#     <div class="tables-container">
#         <div class="table-wrapper">
#             <h4>All Characters (Global %)</h4>
#             <table border="1" class="dataframe table-sm" id="table1">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Character</th>
#       <th>Percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>' '</td>
#       <td>23.8369%</td>
#     </tr>
#     <tr>
#       <td>'e'</td>
#       <td>6.5553%</td>
#     </tr>
#     <tr>
#       <td>'t'</td>
#       <td>5.0971%</td>
#     </tr>
#     <tr>
#       <td>'r'</td>
#       <td>4.0658%</td>
#     </tr>
#     <tr>
#       <td>'i'</td>
#       <td>3.7536%</td>
#     </tr>
#     <tr>
#       <td>'n'</td>
#       <td>3.5585%</td>
#     </tr>
#     <tr>
#       <td>'a'</td>
#       <td>3.5395%</td>
#     </tr>
#     <tr>
#       <td>'\n'</td>
#       <td>3.2972%</td>
#     </tr>
#     <tr>
#       <td>'s'</td>
#       <td>3.2594%</td>
#     </tr>
#     <tr>
#       <td>'o'</td>
#       <td>2.9798%</td>
#     </tr>
#     <tr>
#       <td>'l'</td>
#       <td>2.1937%</td>
#     </tr>
#     <tr>
#       <td>'u'</td>
#       <td>1.8349%</td>
#     </tr>
#     <tr>
#       <td>'d'</td>
#       <td>1.8246%</td>
#     </tr>
#     <tr>
#       <td>'c'</td>
#       <td>1.7011%</td>
#     </tr>
#     <tr>
#       <td>','</td>
#       <td>1.6961%</td>
#     </tr>
#     <tr>
#       <td>'p'</td>
#       <td>1.4147%</td>
#     </tr>
#     <tr>
#       <td>'h'</td>
#       <td>1.4075%</td>
#     </tr>
#     <tr>
#       <td>')'</td>
#       <td>1.3769%</td>
#     </tr>
#     <tr>
#       <td>'('</td>
#       <td>1.3765%</td>
#     </tr>
#     <tr>
#       <td>'m'</td>
#       <td>1.3577%</td>
#     </tr>
#     <tr>
#       <td>'.'</td>
#       <td>1.3065%</td>
#     </tr>
#     <tr>
#       <td>'f'</td>
#       <td>1.1261%</td>
#     </tr>
#     <tr>
#       <td>'g'</td>
#       <td>1.0020%</td>
#     </tr>
#     <tr>
#       <td>'='</td>
#       <td>0.8018%</td>
#     </tr>
#     <tr>
#       <td>'1'</td>
#       <td>0.7972%</td>
#     </tr>
#     <tr>
#       <td>'/'</td>
#       <td>0.7492%</td>
#     </tr>
#     <tr>
#       <td>';'</td>
#       <td>0.7333%</td>
#     </tr>
#     <tr>
#       <td>'b'</td>
#       <td>0.6927%</td>
#     </tr>
#     <tr>
#       <td>'0'</td>
#       <td>0.6658%</td>
#     </tr>
#     <tr>
#       <td>'y'</td>
#       <td>0.6136%</td>
#     </tr>
#     <tr>
#       <td>'_'</td>
#       <td>0.6106%</td>
#     </tr>
#     <tr>
#       <td>'['</td>
#       <td>0.6080%</td>
#     </tr>
#     <tr>
#       <td>']'</td>
#       <td>0.6076%</td>
#     </tr>
#     <tr>
#       <td>'v'</td>
#       <td>0.6064%</td>
#     </tr>
#     <tr>
#       <td>'"'</td>
#       <td>0.5662%</td>
#     </tr>
#     <tr>
#       <td>'x'</td>
#       <td>0.5347%</td>
#     </tr>
#     <tr>
#       <td>'2'</td>
#       <td>0.5323%</td>
#     </tr>
#     <tr>
#       <td>'*'</td>
#       <td>0.5029%</td>
#     </tr>
#     <tr>
#       <td>':'</td>
#       <td>0.4619%</td>
#     </tr>
#     <tr>
#       <td>'w'</td>
#       <td>0.4465%</td>
#     </tr>
#     <tr>
#       <td>'-'</td>
#       <td>0.4397%</td>
#     </tr>
#     <tr>
#       <td>'&gt;'</td>
#       <td>0.4162%</td>
#     </tr>
#     <tr>
#       <td>'{'</td>
#       <td>0.4106%</td>
#     </tr>
#     <tr>
#       <td>'}'</td>
#       <td>0.4105%</td>
#     </tr>
#     <tr>
#       <td>'3'</td>
#       <td>0.4070%</td>
#     </tr>
#     <tr>
#       <td>'\t'</td>
#       <td>0.3884%</td>
#     </tr>
#     <tr>
#       <td>'T'</td>
#       <td>0.3856%</td>
#     </tr>
#     <tr>
#       <td>'5'</td>
#       <td>0.3530%</td>
#     </tr>
#     <tr>
#       <td>'4'</td>
#       <td>0.3465%</td>
#     </tr>
#     <tr>
#       <td>'k'</td>
#       <td>0.3311%</td>
#     </tr>
#     <tr>
#       <td>"'"</td>
#       <td>0.3305%</td>
#     </tr>
#     <tr>
#       <td>'S'</td>
#       <td>0.3048%</td>
#     </tr>
#     <tr>
#       <td>'6'</td>
#       <td>0.2919%</td>
#     </tr>
#     <tr>
#       <td>'7'</td>
#       <td>0.2816%</td>
#     </tr>
#     <tr>
#       <td>'&lt;'</td>
#       <td>0.2770%</td>
#     </tr>
#     <tr>
#       <td>'9'</td>
#       <td>0.2760%</td>
#     </tr>
#     <tr>
#       <td>'8'</td>
#       <td>0.2698%</td>
#     </tr>
#     <tr>
#       <td>'A'</td>
#       <td>0.2685%</td>
#     </tr>
#     <tr>
#       <td>'E'</td>
#       <td>0.2577%</td>
#     </tr>
#     <tr>
#       <td>'I'</td>
#       <td>0.2326%</td>
#     </tr>
#     <tr>
#       <td>'C'</td>
#       <td>0.2198%</td>
#     </tr>
#     <tr>
#       <td>'N'</td>
#       <td>0.2071%</td>
#     </tr>
#     <tr>
#       <td>'q'</td>
#       <td>0.1784%</td>
#     </tr>
#     <tr>
#       <td>'L'</td>
#       <td>0.1776%</td>
#     </tr>
#     <tr>
#       <td>'+'</td>
#       <td>0.1726%</td>
#     </tr>
#     <tr>
#       <td>'B'</td>
#       <td>0.1500%</td>
#     </tr>
#     <tr>
#       <td>'R'</td>
#       <td>0.1424%</td>
#     </tr>
#     <tr>
#       <td>'j'</td>
#       <td>0.1405%</td>
#     </tr>
#     <tr>
#       <td>'P'</td>
#       <td>0.1297%</td>
#     </tr>
#     <tr>
#       <td>'D'</td>
#       <td>0.1251%</td>
#     </tr>
#     <tr>
#       <td>'M'</td>
#       <td>0.1176%</td>
#     </tr>
#     <tr>
#       <td>'O'</td>
#       <td>0.1164%</td>
#     </tr>
#     <tr>
#       <td>'F'</td>
#       <td>0.1158%</td>
#     </tr>
#     <tr>
#       <td>'@'</td>
#       <td>0.1157%</td>
#     </tr>
#     <tr>
#       <td>'z'</td>
#       <td>0.1063%</td>
#     </tr>
#     <tr>
#       <td>'V'</td>
#       <td>0.1000%</td>
#     </tr>
#     <tr>
#       <td>'#'</td>
#       <td>0.0971%</td>
#     </tr>
#     <tr>
#       <td>'G'</td>
#       <td>0.0756%</td>
#     </tr>
#     <tr>
#       <td>'H'</td>
#       <td>0.0689%</td>
#     </tr>
#     <tr>
#       <td>'!'</td>
#       <td>0.0678%</td>
#     </tr>
#     <tr>
#       <td>'&amp;'</td>
#       <td>0.0592%</td>
#     </tr>
#     <tr>
#       <td>'U'</td>
#       <td>0.0547%</td>
#     </tr>
#     <tr>
#       <td>'W'</td>
#       <td>0.0497%</td>
#     </tr>
#     <tr>
#       <td>'|'</td>
#       <td>0.0478%</td>
#     </tr>
#     <tr>
#       <td>'`'</td>
#       <td>0.0456%</td>
#     </tr>
#     <tr>
#       <td>'K'</td>
#       <td>0.0455%</td>
#     </tr>
#     <tr>
#       <td>'\\'</td>
#       <td>0.0385%</td>
#     </tr>
#     <tr>
#       <td>'$'</td>
#       <td>0.0369%</td>
#     </tr>
#     <tr>
#       <td>'%'</td>
#       <td>0.0321%</td>
#     </tr>
#     <tr>
#       <td>'X'</td>
#       <td>0.0227%</td>
#     </tr>
#     <tr>
#       <td>'?'</td>
#       <td>0.0223%</td>
#     </tr>
#     <tr>
#       <td>'Q'</td>
#       <td>0.0222%</td>
#     </tr>
#     <tr>
#       <td>'Y'</td>
#       <td>0.0156%</td>
#     </tr>
#     <tr>
#       <td>'J'</td>
#       <td>0.0134%</td>
#     </tr>
#     <tr>
#       <td>'^'</td>
#       <td>0.0116%</td>
#     </tr>
#     <tr>
#       <td>'Z'</td>
#       <td>0.0089%</td>
#     </tr>
#     <tr>
#       <td>'~'</td>
#       <td>0.0061%</td>
#     </tr>
#   </tbody>
# </table>
#         </div>
#         <div class="table-wrapper">
#             <h4>Letters Only (%)</h4>
#             <table border="1" class="dataframe table-sm" id="table2">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Character</th>
#       <th>Percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>e</td>
#       <td>12.1961%</td>
#     </tr>
#     <tr>
#       <td>t</td>
#       <td>9.4830%</td>
#     </tr>
#     <tr>
#       <td>r</td>
#       <td>7.5644%</td>
#     </tr>
#     <tr>
#       <td>i</td>
#       <td>6.9835%</td>
#     </tr>
#     <tr>
#       <td>n</td>
#       <td>6.6206%</td>
#     </tr>
#     <tr>
#       <td>a</td>
#       <td>6.5853%</td>
#     </tr>
#     <tr>
#       <td>s</td>
#       <td>6.0641%</td>
#     </tr>
#     <tr>
#       <td>o</td>
#       <td>5.5439%</td>
#     </tr>
#     <tr>
#       <td>l</td>
#       <td>4.0813%</td>
#     </tr>
#     <tr>
#       <td>u</td>
#       <td>3.4138%</t
# ================================================================================
#     <style>
#         .tables-container {
#             display: flex;
#             gap: 20px;
#             flex-wrap: wrap;
#         }
#         .table-wrapper {
#             flex: 1;
#             min-width: 200px;
#             max-height: 600px;
#             overflow-y: auto;
#         }
#         .table-wrapper h4 {
#             text-align: center;
#             margin-bottom: 10px;
#             color: #333;
#         }
#         .table-sm {
#             font-size: 12px;
#             width: 100%;
#         }
#         .table-sm th, .table-sm td {
#             padding: 4px 8px;
#             text-align: left;
#         }
#         .table-sm th {
#             background-color: #f8f9fa;
#             font-weight: bold;
#         }
#         .table-sm tr:nth-child(even) {
#             background-color: #f8f9fa;
#         }
#     </style>
#
#     <h2>Character Frequency Analysis for: gutenberg</h2>
#     <div class="tables-container">
#         <div class="table-wrapper">
#             <h4>All Characters (Global %)</h4>
#             <table border="1" class="dataframe table-sm" id="table1">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Character</th>
#       <th>Percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>' '</td>
#       <td>16.3645%</td>
#     </tr>
#     <tr>
#       <td>'e'</td>
#       <td>9.5734%</td>
#     </tr>
#     <tr>
#       <td>'t'</td>
#       <td>6.6509%</td>
#     </tr>
#     <tr>
#       <td>'a'</td>
#       <td>5.9682%</td>
#     </tr>
#     <tr>
#       <td>'o'</td>
#       <td>5.8744%</td>
#     </tr>
#     <tr>
#       <td>'n'</td>
#       <td>5.2249%</td>
#     </tr>
#     <tr>
#       <td>'i'</td>
#       <td>4.9385%</td>
#     </tr>
#     <tr>
#       <td>'s'</td>
#       <td>4.7807%</td>
#     </tr>
#     <tr>
#       <td>'h'</td>
#       <td>4.5546%</td>
#     </tr>
#     <tr>
#       <td>'r'</td>
#       <td>4.4954%</td>
#     </tr>
#     <tr>
#       <td>'d'</td>
#       <td>3.2242%</td>
#     </tr>
#     <tr>
#       <td>'l'</td>
#       <td>3.0327%</td>
#     </tr>
#     <tr>
#       <td>'u'</td>
#       <td>2.2771%</td>
#     </tr>
#     <tr>
#       <td>'\n'</td>
#       <td>2.0959%</td>
#     </tr>
#     <tr>
#       <td>'c'</td>
#       <td>1.8899%</td>
#     </tr>
#     <tr>
#       <td>'m'</td>
#       <td>1.8858%</td>
#     </tr>
#     <tr>
#       <td>'f'</td>
#       <td>1.6242%</td>
#     </tr>
#     <tr>
#       <td>'w'</td>
#       <td>1.5566%</td>
#     </tr>
#     <tr>
#       <td>','</td>
#       <td>1.4966%</td>
#     </tr>
#     <tr>
#       <td>'y'</td>
#       <td>1.4719%</td>
#     </tr>
#     <tr>
#       <td>'g'</td>
#       <td>1.4077%</td>
#     </tr>
#     <tr>
#       <td>'p'</td>
#       <td>1.2661%</td>
#     </tr>
#     <tr>
#       <td>'b'</td>
#       <td>1.0527%</td>
#     </tr>
#     <tr>
#       <td>'.'</td>
#       <td>0.9074%</td>
#     </tr>
#     <tr>
#       <td>'v'</td>
#       <td>0.7693%</td>
#     </tr>
#     <tr>
#       <td>'k'</td>
#       <td>0.5119%</td>
#     </tr>
#     <tr>
#       <td>'I'</td>
#       <td>0.4367%</td>
#     </tr>
#     <tr>
#       <td>'T'</td>
#       <td>0.2648%</td>
#     </tr>
#     <tr>
#       <td>'A'</td>
#       <td>0.2356%</td>
#     </tr>
#     <tr>
#       <td>';'</td>
#       <td>0.1780%</td>
#     </tr>
#     <tr>
#       <td>'S'</td>
#       <td>0.1736%</td>
#     </tr>
#     <tr>
#       <td>'M'</td>
#       <td>0.1378%</td>
#     </tr>
#     <tr>
#       <td>'H'</td>
#       <td>0.1374%</td>
#     </tr>
#     <tr>
#       <td>'-'</td>
#       <td>0.1339%</td>
#     </tr>
#     <tr>
#       <td>'q'</td>
#       <td>0.1320%</td>
#     </tr>
#     <tr>
#       <td>'E'</td>
#       <td>0.1289%</td>
#     </tr>
#     <tr>
#       <td>'x'</td>
#       <td>0.1161%</td>
#     </tr>
#     <tr>
#       <td>'C'</td>
#       <td>0.1132%</td>
#     </tr>
#     <tr>
#       <td>'W'</td>
#       <td>0.1076%</td>
#     </tr>
#     <tr>
#       <td>'B'</td>
#       <td>0.1065%</td>
#     </tr>
#     <tr>
#       <td>'O'</td>
#       <td>0.1046%</td>
#     </tr>
#     <tr>
#       <td>'N'</td>
#       <td>0.1032%</td>
#     </tr>
#     <tr>
#       <td>'P'</td>
#       <td>0.1009%</td>
#     </tr>
#     <tr>
#       <td>'j'</td>
#       <td>0.0987%</td>
#     </tr>
#     <tr>
#       <td>'L'</td>
#       <td>0.0979%</td>
#     </tr>
#     <tr>
#       <td>'R'</td>
#       <td>0.0927%</td>
#     </tr>
#     <tr>
#       <td>'?'</td>
#       <td>0.0890%</td>
#     </tr>
#     <tr>
#       <td>'_'</td>
#       <td>0.0834%</td>
#     </tr>
#     <tr>
#       <td>'D'</td>
#       <td>0.0804%</td>
#     </tr>
#     <tr>
#       <td>'G'</td>
#       <td>0.0770%</td>
#     </tr>
#     <tr>
#       <td>'F'</td>
#       <td>0.0770%</td>
#     </tr>
#     <tr>
#       <td>'!'</td>
#       <td>0.0765%</td>
#     </tr>
#     <tr>
#       <td>':'</td>
#       <td>0.0587%</td>
#     </tr>
#     <tr>
#       <td>'z'</td>
#       <td>0.0497%</td>
#     </tr>
#     <tr>
#       <td>'Y'</td>
#       <td>0.0488%</td>
#     </tr>
#     <tr>
#       <td>'1'</td>
#       <td>0.0446%</td>
#     </tr>
#     <tr>
#       <td>'U'</td>
#       <td>0.0374%</td>
#     </tr>
#     <tr>
#       <td>'J'</td>
#       <td>0.0343%</td>
#     </tr>
#     <tr>
#       <td>'V'</td>
#       <td>0.0343%</td>
#     </tr>
#     <tr>
#       <td>'"'</td>
#       <td>0.0340%</td>
#     </tr>
#     <tr>
#       <td>"'"</td>
#       <td>0.0291%</td>
#     </tr>
#     <tr>
#       <td>'('</td>
#       <td>0.0268%</td>
#     </tr>
#     <tr>
#       <td>')'</td>
#       <td>0.0268%</td>
#     </tr>
#     <tr>
#       <td>'K'</td>
#       <td>0.0259%</td>
#     </tr>
#     <tr>
#       <td>'2'</td>
#       <td>0.0227%</td>
#     </tr>
#     <tr>
#       <td>'['</td>
#       <td>0.0226%</td>
#     </tr>
#     <tr>
#       <td>']'</td>
#       <td>0.0226%</td>
#     </tr>
#     <tr>
#       <td>'0'</td>
#       <td>0.0193%</td>
#     </tr>
#     <tr>
#       <td>'3'</td>
#       <td>0.0182%</td>
#     </tr>
#     <tr>
#       <td>'5'</td>
#       <td>0.0179%</td>
#     </tr>
#     <tr>
#       <td>'8'</td>
#       <td>0.0156%</td>
#     </tr>
#     <tr>
#       <td>'4'</td>
#       <td>0.0152%</td>
#     </tr>
#     <tr>
#       <td>'6'</td>
#       <td>0.0149%</td>
#     </tr>
#     <tr>
#       <td>'7'</td>
#       <td>0.0123%</td>
#     </tr>
#     <tr>
#       <td>'X'</td>
#       <td>0.0113%</td>
#     </tr>
#     <tr>
#       <td>'9'</td>
#       <td>0.0110%</td>
#     </tr>
#     <tr>
#       <td>'Q'</td>
#       <td>0.0091%</td>
#     </tr>
#     <tr>
#       <td>'*'</td>
#       <td>0.0055%</td>
#     </tr>
#     <tr>
#       <td>'Z'</td>
#       <td>0.0038%</td>
#     </tr>
#     <tr>
#       <td>'/'</td>
#       <td>0.0023%</td>
#     </tr>
#     <tr>
#       <td>'&amp;'</td>
#       <td>0.0011%</td>
#     </tr>
#     <tr>
#       <td>'{'</td>
#       <td>0.0007%</td>
#     </tr>
#     <tr>
#       <td>'}'</td>
#       <td>0.0007%</td>
#     </tr>
#     <tr>
#       <td>'^'</td>
#       <td>0.0007%</td>
#     </tr>
#     <tr>
#       <td>'|'</td>
#       <td>0.0006%</td>
#     </tr>
#     <tr>
#       <td>'$'</td>
#       <td>0.0004%</td>
#     </tr>
#     <tr>
#       <td>'='</td>
#       <td>0.0004%</td>
#     </tr>
#     <tr>
#       <td>'~'</td>
#       <td>0.0004%</td>
#     </tr>
#     <tr>
#       <td>'+'</td>
#       <td>0.0003%</td>
#     </tr>
#     <tr>
#       <td>'#'</td>
#       <td>0.0002%</td>
#     </tr>
#     <tr>
#       <td>'%'</td>
#       <td>0.0001%</td>
#     </tr>
#     <tr>
#       <td>'`'</td>
#       <td>0.0001%</td>
#     </tr>
#     <tr>
#       <td>'&lt;'</td>
#       <td>0.0000%</td>
#     </tr>
#     <tr>
#       <td>'&gt;'</td>
#       <td>0.0000%</td>
#     </tr>
#     <tr>
#       <td>'\t'</td>
#       <td>0.0000%</td>
#     </tr>
#   </tbody>
# </table>
#         </div>
#         <div class="table-wrapper">
#             <h4>Letters Only (%)</h4>
#             <table border="1" class="dataframe table-sm" id="table2">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Character</th>
#       <th>Percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>e</td>
#       <td>12.3995%</td>
#     </tr>
#     <tr>
#       <td>t</td>
#       <td>8.6142%</td>
#     </tr>
#     <tr>
#       <td>a</td>
#       <td>7.7300%</td>
#     </tr>
#     <tr>
#       <td>o</td>
#       <td>7.6085%</td>
#     </tr>
#     <tr>
#       <td>n</td>
#       <td>6.7673%</td>
#     </tr>
#     <tr>
#       <td>i</td>
#       <td>6.3964%</td>
#     </tr>
#     <tr>
#       <td>s</td>
#       <td>6.1920%</td>
#     </tr>
#     <tr>
#       <td>h</td>
#       <td>5.8992%</td>
#     </tr>
#     <tr>
#       <td>r</td>
#       <td>5.8225%</td>
#     </tr>
#     <tr>
#       <td>d</td>
#       <td>4.1760%</td>
#     </tr>
#     <tr>
#       <td>l</td>
#       <td>3.9279%</td>
#     </tr>
#     <tr>
#       <td>u</td>
#       <td>2.9493%</td>
#     </tr>
# ================================================================================
#     <style>
#         .tables-container {
#             display: flex;
#             gap: 20px;
#             flex-wrap: wrap;
#         }
#         .table-wrapper {
#             flex: 1;
#             min-width: 200px;
#             max-height: 600px;
#             overflow-y: auto;
#         }
#         .table-wrapper h4 {
#             text-align: center;
#             margin-bottom: 10px;
#             color: #333;
#         }
#         .table-sm {
#             font-size: 12px;
#             width: 100%;
#         }
#         .table-sm th, .table-sm td {
#             padding: 4px 8px;
#             text-align: left;
#         }
#         .table-sm th {
#             background-color: #f8f9fa;
#             font-weight: bold;
#         }
#         .table-sm tr:nth-child(even) {
#             background-color: #f8f9fa;
#         }
#     </style>
#
#     <h2>Character Frequency Analysis for: cartigratis</h2>
#     <div class="tables-container">
#         <div class="table-wrapper">
#             <h4>All Characters (Global %)</h4>
#             <table border="1" class="dataframe table-sm" id="table1">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Character</th>
#       <th>Percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>' '</td>
#       <td>15.6248%</td>
#     </tr>
#     <tr>
#       <td>'e'</td>
#       <td>8.9102%</td>
#     </tr>
#     <tr>
#       <td>'i'</td>
#       <td>7.6959%</td>
#     </tr>
#     <tr>
#       <td>'a'</td>
#       <td>7.6228%</td>
#     </tr>
#     <tr>
#       <td>'r'</td>
#       <td>5.1685%</td>
#     </tr>
#     <tr>
#       <td>'u'</td>
#       <td>4.8935%</td>
#     </tr>
#     <tr>
#       <td>'n'</td>
#       <td>4.8757%</td>
#     </tr>
#     <tr>
#       <td>'t'</td>
#       <td>4.5224%</td>
#     </tr>
#     <tr>
#       <td>'c'</td>
#       <td>3.9280%</td>
#     </tr>
#     <tr>
#       <td>'l'</td>
#       <td>3.4080%</td>
#     </tr>
#     <tr>
#       <td>'s'</td>
#       <td>3.2407%</td>
#     </tr>
#     <tr>
#       <td>'o'</td>
#       <td>2.9418%</td>
#     </tr>
#     <tr>
#       <td>'ă'</td>
#       <td>2.8997%</td>
#     </tr>
#     <tr>
#       <td>'d'</td>
#       <td>2.4592%</td>
#     </tr>
#     <tr>
#       <td>'m'</td>
#       <td>2.4535%</td>
#     </tr>
#     <tr>
#       <td>'p'</td>
#       <td>2.2894%</td>
#     </tr>
#     <tr>
#       <td>'\n'</td>
#       <td>1.7583%</td>
#     </tr>
#     <tr>
#       <td>','</td>
#       <td>1.3613%</td>
#     </tr>
#     <tr>
#       <td>'î'</td>
#       <td>1.2184%</td>
#     </tr>
#     <tr>
#       <td>'.'</td>
#       <td>1.0640%</td>
#     </tr>
#     <tr>
#       <td>'v'</td>
#       <td>0.9226%</td>
#     </tr>
#     <tr>
#       <td>'f'</td>
#       <td>0.8645%</td>
#     </tr>
#     <tr>
#       <td>'b'</td>
#       <td>0.7338%</td>
#     </tr>
#     <tr>
#       <td>'g'</td>
#       <td>0.6655%</td>
#     </tr>
#     <tr>
#       <td>'-'</td>
#       <td>0.6326%</td>
#     </tr>
#     <tr>
#       <td>'z'</td>
#       <td>0.5173%</td>
#     </tr>
#     <tr>
#       <td>'â'</td>
#       <td>0.4778%</td>
#     </tr>
#     <tr>
#       <td>'h'</td>
#       <td>0.3252%</td>
#     </tr>
#     <tr>
#       <td>'ș'</td>
#       <td>0.2927%</td>
#     </tr>
#     <tr>
#       <td>'A'</td>
#       <td>0.2216%</td>
#     </tr>
#     <tr>
#       <td>'D'</td>
#       <td>0.2097%</td>
#     </tr>
#     <tr>
#       <td>'C'</td>
#       <td>0.1730%</td>
#     </tr>
#     <tr>
#       <td>'j'</td>
#       <td>0.1592%</td>
#     </tr>
#     <tr>
#       <td>'S'</td>
#       <td>0.1591%</td>
#     </tr>
#     <tr>
#       <td>'!'</td>
#       <td>0.1584%</td>
#     </tr>
#     <tr>
#       <td>'%'</td>
#       <td>0.1318%</td>
#     </tr>
#     <tr>
#       <td>'N'</td>
#       <td>0.1265%</td>
#     </tr>
#     <tr>
#       <td>'M'</td>
#       <td>0.1219%</td>
#     </tr>
#     <tr>
#       <td>'E'</td>
#       <td>0.1211%</td>
#     </tr>
#     <tr>
#       <td>'P'</td>
#       <td>0.1193%</td>
#     </tr>
#     <tr>
#       <td>'?'</td>
#       <td>0.1136%</td>
#     </tr>
#     <tr>
#       <td>':'</td>
#       <td>0.1077%</td>
#     </tr>
#     <tr>
#       <td>'ț'</td>
#       <td>0.1033%</td>
#     </tr>
#     <tr>
#       <td>'I'</td>
#       <td>0.1002%</td>
#     </tr>
#     <tr>
#       <td>'7'</td>
#       <td>0.0968%</td>
#     </tr>
#     <tr>
#       <td>'T'</td>
#       <td>0.0944%</td>
#     </tr>
#     <tr>
#       <td>'1'</td>
#       <td>0.0940%</td>
#     </tr>
#     <tr>
#       <td>'&amp;'</td>
#       <td>0.0888%</td>
#     </tr>
#     <tr>
#       <td>'x'</td>
#       <td>0.0768%</td>
#     </tr>
#     <tr>
#       <td>'L'</td>
#       <td>0.0732%</td>
#     </tr>
#     <tr>
#       <td>'0'</td>
#       <td>0.0687%</td>
#     </tr>
#     <tr>
#       <td>'Î'</td>
#       <td>0.0679%</td>
#     </tr>
#     <tr>
#       <td>'2'</td>
#       <td>0.0650%</td>
#     </tr>
#     <tr>
#       <td>'O'</td>
#       <td>0.0628%</td>
#     </tr>
#     <tr>
#       <td>';'</td>
#       <td>0.0621%</td>
#     </tr>
#     <tr>
#       <td>'B'</td>
#       <td>0.0608%</td>
#     </tr>
#     <tr>
#       <td>'y'</td>
#       <td>0.0590%</td>
#     </tr>
#     <tr>
#       <td>'8'</td>
#       <td>0.0552%</td>
#     </tr>
#     <tr>
#       <td>'5'</td>
#       <td>0.0539%</td>
#     </tr>
#     <tr>
#       <td>'R'</td>
#       <td>0.0519%</td>
#     </tr>
#     <tr>
#       <td>'4'</td>
#       <td>0.0477%</td>
#     </tr>
#     <tr>
#       <td>'F'</td>
#       <td>0.0475%</td>
#     </tr>
#     <tr>
#       <td>'V'</td>
#       <td>0.0469%</td>
#     </tr>
#     <tr>
#       <td>'9'</td>
#       <td>0.0454%</td>
#     </tr>
#     <tr>
#       <td>'G'</td>
#       <td>0.0432%</td>
#     </tr>
#     <tr>
#       <td>'H'</td>
#       <td>0.0417%</td>
#     </tr>
#     <tr>
#       <td>'3'</td>
#       <td>0.0403%</td>
#     </tr>
#     <tr>
#       <td>'k'</td>
#       <td>0.0402%</td>
#     </tr>
#     <tr>
#       <td>'+'</td>
#       <td>0.0392%</td>
#     </tr>
#     <tr>
#       <td>'/'</td>
#       <td>0.0355%</td>
#     </tr>
#     <tr>
#       <td>'U'</td>
#       <td>0.0346%</td>
#     </tr>
#     <tr>
#       <td>'6'</td>
#       <td>0.0250%</td>
#     </tr>
#     <tr>
#       <td>'J'</td>
#       <td>0.0241%</td>
#     </tr>
#     <tr>
#       <td>'"'</td>
#       <td>0.0232%</td>
#     </tr>
#     <tr>
#       <td>'w'</td>
#       <td>0.0224%</td>
#     </tr>
#     <tr>
#       <td>'K'</td>
#       <td>0.0200%</td>
#     </tr>
#     <tr>
#       <td>'Ș'</td>
#       <td>0.0177%</td>
#     </tr>
#     <tr>
#       <td>"'"</td>
#       <td>0.0150%</td>
#     </tr>
#     <tr>
#       <td>'W'</td>
#       <td>0.0141%</td>
#     </tr>
#     <tr>
#       <td>'('</td>
#       <td>0.0140%</td>
#     </tr>
#     <tr>
#       <td>')'</td>
#       <td>0.0134%</td>
#     </tr>
#     <tr>
#       <td>'Z'</td>
#       <td>0.0095%</td>
#     </tr>
#     <tr>
#       <td>'&gt;'</td>
#       <td>0.0059%</td>
#     </tr>
#     <tr>
#       <td>'*'</td>
#       <td>0.0057%</td>
#     </tr>
#     <tr>
#       <td>'Ă'</td>
#       <td>0.0056%</td>
#     </tr>
#     <tr>
#       <td>'_'</td>
#       <td>0.0056%</td>
#     </tr>
#     <tr>
#       <td>'#'</td>
#       <td>0.0042%</td>
#     </tr>
#     <tr>
#       <td>'q'</td>
#       <td>0.0040%</td>
#     </tr>
#     <tr>
#       <td>'X'</td>
#       <td>0.0031%</td>
#     </tr>
#     <tr>
#       <td>'Y'</td>
#       <td>0.0028%</td>
#     </tr>
#     <tr>
#       <td>'^'</td>
#       <td>0.0028%</td>
#     </tr>
#     <tr>
#       <td>'@'</td>
#       <td>0.0024%</td>
#     </tr>
#     <tr>
#       <td>'='</td>
#       <td>0.0018%</td>
#     </tr>
#     <tr>
#       <td>'&lt;'</td>
#       <td>0.0016%</td>
#     </tr>
#     <tr>
#       <td>'Q'</td>
#       <td>0.0014%</td>
#     </tr>
#     <tr>
#       <td>'$'</td>
#       <td>0.0012%</td>
#     </tr>
#     <tr>
#       <td>'Ț'</td>
#       <td>0.0009%</td>
#     </tr>
#     <tr>
#       <td>'}'</td>
#       <td>0.0008%</td>
#     </tr>
#     <tr>
#       <td>'~'</td>
#       <td>0.0007%</td>
#     </tr>
#     <tr>
#       <td>'{'</td>
#       <td>0.0007%</td>
#     </tr>
#     <tr>
#       <td>']'</td>
#       <td>0.0004%</td>
#     </tr>
#     <tr>
#       <td>'Â'</td>
#       <td>0.0004%</td>
#     </tr>
#     <tr>
#       <td>'\\'</td>
#       <td>0.0003%</td>
#     </tr>
#     <tr>
#       <td>'['</td>
#       <td>0.0002%</td>
#     </tr>
#     <tr>
#       <td>'|'</td>
#       <td>0.0002%</td>
#     </tr>
#     <tr>
#       <td>'`'</td>
#       <td>0.0001%</td>
#     </tr>
#   </tbody>
# </table>
#         </div>
#         <div class="table-wrapper">
#             <h4>Letters Only (%)</h4>
#             <table border="1" class="dataframe table-sm" id="table2">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Character</th>
#       <th>Percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>e</td>
#       <td>11
# ================================================================================
#     <style>
#         .tables-container {
#             display: flex;
#             gap: 20px;
#             flex-wrap: wrap;
#         }
#         .table-wrapper {
#             flex: 1;
#             min-width: 200px;
#             max-height: 600px;
#             overflow-y: auto;
#         }
#         .table-wrapper h4 {
#             text-align: center;
#             margin-bottom: 10px;
#             color: #333;
#         }
#         .table-sm {
#             font-size: 12px;
#             width: 100%;
#         }
#         .table-sm th, .table-sm td {
#             padding: 4px 8px;
#             text-align: left;
#         }
#         .table-sm th {
#             background-color: #f8f9fa;
#             font-weight: bold;
#         }
#         .table-sm tr:nth-child(even) {
#             background-color: #f8f9fa;
#         }
#     </style>
#
#     <h2>Character Frequency Analysis for: newsgroup</h2>
#     <div class="tables-container">
#         <div class="table-wrapper">
#             <h4>All Characters (Global %)</h4>
#             <table border="1" class="dataframe table-sm" id="table1">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Character</th>
#       <th>Percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>' '</td>
#       <td>16.6518%</td>
#     </tr>
#     <tr>
#       <td>'e'</td>
#       <td>7.7053%</td>
#     </tr>
#     <tr>
#       <td>'t'</td>
#       <td>5.6713%</td>
#     </tr>
#     <tr>
#       <td>'o'</td>
#       <td>5.0586%</td>
#     </tr>
#     <tr>
#       <td>'a'</td>
#       <td>4.9891%</td>
#     </tr>
#     <tr>
#       <td>'i'</td>
#       <td>4.4845%</td>
#     </tr>
#     <tr>
#       <td>'n'</td>
#       <td>4.3427%</td>
#     </tr>
#     <tr>
#       <td>'s'</td>
#       <td>4.1694%</td>
#     </tr>
#     <tr>
#       <td>'r'</td>
#       <td>3.9614%</td>
#     </tr>
#     <tr>
#       <td>'h'</td>
#       <td>2.8830%</td>
#     </tr>
#     <tr>
#       <td>'l'</td>
#       <td>2.6326%</td>
#     </tr>
#     <tr>
#       <td>'\n'</td>
#       <td>2.3862%</td>
#     </tr>
#     <tr>
#       <td>'d'</td>
#       <td>2.2942%</td>
#     </tr>
#     <tr>
#       <td>'c'</td>
#       <td>2.1454%</td>
#     </tr>
#     <tr>
#       <td>'u'</td>
#       <td>2.0920%</td>
#     </tr>
#     <tr>
#       <td>'m'</td>
#       <td>1.7441%</td>
#     </tr>
#     <tr>
#       <td>'.'</td>
#       <td>1.5924%</td>
#     </tr>
#     <tr>
#       <td>'p'</td>
#       <td>1.3719%</td>
#     </tr>
#     <tr>
#       <td>'-'</td>
#       <td>1.3480%</td>
#     </tr>
#     <tr>
#       <td>'g'</td>
#       <td>1.2572%</td>
#     </tr>
#     <tr>
#       <td>'y'</td>
#       <td>1.2407%</td>
#     </tr>
#     <tr>
#       <td>'f'</td>
#       <td>1.1927%</td>
#     </tr>
#     <tr>
#       <td>'w'</td>
#       <td>1.1633%</td>
#     </tr>
#     <tr>
#       <td>'b'</td>
#       <td>0.9933%</td>
#     </tr>
#     <tr>
#       <td>'&gt;'</td>
#       <td>0.7585%</td>
#     </tr>
#     <tr>
#       <td>','</td>
#       <td>0.7390%</td>
#     </tr>
#     <tr>
#       <td>'v'</td>
#       <td>0.6878%</td>
#     </tr>
#     <tr>
#       <td>'I'</td>
#       <td>0.5756%</td>
#     </tr>
#     <tr>
#       <td>'A'</td>
#       <td>0.5718%</td>
#     </tr>
#     <tr>
#       <td>'k'</td>
#       <td>0.5495%</td>
#     </tr>
#     <tr>
#       <td>"'"</td>
#       <td>0.4955%</td>
#     </tr>
#     <tr>
#       <td>':'</td>
#       <td>0.4933%</td>
#     </tr>
#     <tr>
#       <td>'S'</td>
#       <td>0.4392%</td>
#     </tr>
#     <tr>
#       <td>'1'</td>
#       <td>0.4234%</td>
#     </tr>
#     <tr>
#       <td>'T'</td>
#       <td>0.3823%</td>
#     </tr>
#     <tr>
#       <td>'0'</td>
#       <td>0.3693%</td>
#     </tr>
#     <tr>
#       <td>'='</td>
#       <td>0.3505%</td>
#     </tr>
#     <tr>
#       <td>'M'</td>
#       <td>0.3309%</td>
#     </tr>
#     <tr>
#       <td>')'</td>
#       <td>0.3167%</td>
#     </tr>
#     <tr>
#       <td>'('</td>
#       <td>0.3099%</td>
#     </tr>
#     <tr>
#       <td>'_'</td>
#       <td>0.3076%</td>
#     </tr>
#     <tr>
#       <td>'C'</td>
#       <td>0.3054%</td>
#     </tr>
#     <tr>
#       <td>'*'</td>
#       <td>0.3050%</td>
#     </tr>
#     <tr>
#       <td>'2'</td>
#       <td>0.2828%</td>
#     </tr>
#     <tr>
#       <td>'X'</td>
#       <td>0.2801%</td>
#     </tr>
#     <tr>
#       <td>'D'</td>
#       <td>0.2614%</td>
#     </tr>
#     <tr>
#       <td>'R'</td>
#       <td>0.2601%</td>
#     </tr>
#     <tr>
#       <td>'N'</td>
#       <td>0.2595%</td>
#     </tr>
#     <tr>
#       <td>'3'</td>
#       <td>0.2515%</td>
#     </tr>
#     <tr>
#       <td>'"'</td>
#       <td>0.2431%</td>
#     </tr>
#     <tr>
#       <td>'E'</td>
#       <td>0.2367%</td>
#     </tr>
#     <tr>
#       <td>'@'</td>
#       <td>0.2365%</td>
#     </tr>
#     <tr>
#       <td>'5'</td>
#       <td>0.2279%</td>
#     </tr>
#     <tr>
#       <td>'P'</td>
#       <td>0.2207%</td>
#     </tr>
#     <tr>
#       <td>'9'</td>
#       <td>0.2198%</td>
#     </tr>
#     <tr>
#       <td>'4'</td>
#       <td>0.2166%</td>
#     </tr>
#     <tr>
#       <td>'F'</td>
#       <td>0.2161%</td>
#     </tr>
#     <tr>
#       <td>'B'</td>
#       <td>0.2154%</td>
#     </tr>
#     <tr>
#       <td>'\t'</td>
#       <td>0.2096%</td>
#     </tr>
#     <tr>
#       <td>'O'</td>
#       <td>0.1987%</td>
#     </tr>
#     <tr>
#       <td>'W'</td>
#       <td>0.1911%</td>
#     </tr>
#     <tr>
#       <td>'H'</td>
#       <td>0.1890%</td>
#     </tr>
#     <tr>
#       <td>'6'</td>
#       <td>0.1883%</td>
#     </tr>
#     <tr>
#       <td>'L'</td>
#       <td>0.1838%</td>
#     </tr>
#     <tr>
#       <td>'8'</td>
#       <td>0.1818%</td>
#     </tr>
#     <tr>
#       <td>'G'</td>
#       <td>0.1729%</td>
#     </tr>
#     <tr>
#       <td>'x'</td>
#       <td>0.1712%</td>
#     </tr>
#     <tr>
#       <td>'7'</td>
#       <td>0.1657%</td>
#     </tr>
#     <tr>
#       <td>'?'</td>
#       <td>0.1578%</td>
#     </tr>
#     <tr>
#       <td>'/'</td>
#       <td>0.1569%</td>
#     </tr>
#     <tr>
#       <td>'j'</td>
#       <td>0.1534%</td>
#     </tr>
#     <tr>
#       <td>'U'</td>
#       <td>0.1420%</td>
#     </tr>
#     <tr>
#       <td>'J'</td>
#       <td>0.1209%</td>
#     </tr>
#     <tr>
#       <td>'|'</td>
#       <td>0.1108%</td>
#     </tr>
#     <tr>
#       <td>'!'</td>
#       <td>0.1074%</td>
#     </tr>
#     <tr>
#       <td>'K'</td>
#       <td>0.1048%</td>
#     </tr>
#     <tr>
#       <td>'&lt;'</td>
#       <td>0.1045%</td>
#     </tr>
#     <tr>
#       <td>'V'</td>
#       <td>0.1026%</td>
#     </tr>
#     <tr>
#       <td>'Y'</td>
#       <td>0.0893%</td>
#     </tr>
#     <tr>
#       <td>'+'</td>
#       <td>0.0836%</td>
#     </tr>
#     <tr>
#       <td>'^'</td>
#       <td>0.0826%</td>
#     </tr>
#     <tr>
#       <td>'z'</td>
#       <td>0.0791%</td>
#     </tr>
#     <tr>
#       <td>'#'</td>
#       <td>0.0779%</td>
#     </tr>
#     <tr>
#       <td>'$'</td>
#       <td>0.0763%</td>
#     </tr>
#     <tr>
#       <td>'Q'</td>
#       <td>0.0730%</td>
#     </tr>
#     <tr>
#       <td>'\\'</td>
#       <td>0.0717%</td>
#     </tr>
#     <tr>
#       <td>';'</td>
#       <td>0.0708%</td>
#     </tr>
#     <tr>
#       <td>'%'</td>
#       <td>0.0702%</td>
#     </tr>
#     <tr>
#       <td>'q'</td>
#       <td>0.0669%</td>
#     </tr>
#     <tr>
#       <td>']'</td>
#       <td>0.0618%</td>
#     </tr>
#     <tr>
#       <td>'['</td>
#       <td>0.0585%</td>
#     </tr>
#     <tr>
#       <td>'Z'</td>
#       <td>0.0559%</td>
#     </tr>
#     <tr>
#       <td>'&amp;'</td>
#       <td>0.0533%</td>
#     </tr>
#     <tr>
#       <td>'`'</td>
#       <td>0.0475%</td>
#     </tr>
#     <tr>
#       <td>'~'</td>
#       <td>0.0460%</td>
#     </tr>
#     <tr>
#       <td>'}'</td>
#       <td>0.0062%</td>
#     </tr>
#     <tr>
#       <td>'{'</td>
#       <td>0.0049%</td>
#     </tr>
#   </tbody>
# </table>
#         </div>
#         <div class="table-wrapper">
#             <h4>Letters Only (%)</h4>
#             <table border="1" class="dataframe table-sm" id="table2">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Character</th>
#       <th>Percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>e</td>
#       <td>11.1220%</td>
#     </tr>
#     <tr>
#       <td>t</td>
#       <td>8.1860%</td>
#     </tr>
#     <tr>
#       <td>o</td>
#       <td>7.3017%</td>
#     </tr>
#     <tr>
#       <td>a</td>
#       <td>7.2014%</td>
#     </tr>
#     <tr>
#       <td>i</td>
#       <td>6.4730%</td>
#     </tr>
#     <tr>
#       <td>n</td>
#       <td>6.2684%</td>
#     </tr>
#     <tr>
#       <td>s</td>
#       <td>6.0182%</td>
#     </tr>
#     <tr>
#       <td>r</td>
#       <td>5.7179%</td>
#     </tr>
#     <tr>
#       <td>h</td>
#       <td>4.1615%</td>
#     </tr>
#     <tr>
#       <td>l</td>
#       <td>3.7999%</td>
#     </t
# ================================================================================
