# %%
import sys
sys.path.append('..')
from src.core.evaluator import Evaluator

# %%
ev = Evaluator(debug=True)\
    .load_keyoard(keyboard_file='../src/data/keyboards/ansi_60_percent.json').load_distance().load_layout()

ev.render_layout()
# Out:
# Read file: '../src/data/keyboards/ansi_60_percent.json'
# Calculating distance
# Distance Calculator Invoked
# Obtained '7ab8d9e444d24cdc0b50bc9cd265a306' hash for current keyboard
# Loading Cache
# ✅ Successfully loaded data from src/data/distance/distances.pkl
# Calculating costs
# Identified keys of each finger
# Calculating all possible movements and caching in 2D matrix
# cost's for this keyboard have been cached in 2D matrix
# here
# Saved cache
# Layout Loaded Keyboard
#
# ...
# LAYOUT DEBUG - ALL LAYERS
# ...
#
# LAYER 0: 0  :CHAR         =('`', '~')
#  | 1  :CHAR         =('1', '!')        | 2  :CHAR         =('2', '@')        | 3  :CHAR         =('3', '#')
#  | 4  :CHAR         =('4', '$')        | 5  :CHAR         =('5', '%')        | 6  :CHAR         =('6', '^')
#  | 7  :CHAR         =('7', '&')        | 8  :CHAR         =('8', '*')        | 9  :CHAR         =('9', '(')
#  | 10 :CHAR         =('0', ')')        | 11 :CHAR         =('-', '_')        | 12 :CHAR         =('=', '+')
# ...

# %%
import src.data.languages.romanian_standard as ro
ev.layout.apply_language_layout(ro.get_layout())

ev.render_layout()
# Out:
# Applying: 'Romanian Standard' language layout
# --- Layer 0 ---
# --- Layer 1 ---
